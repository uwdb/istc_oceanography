# %% [markdown]
# # Ocean Genomic Analysis with Myria!

# %% [markdown]
# Courtesy of the Chisholm Lab and the Simons Foundation, we have data from ocean expeditions conducted in 2010-2011. In these expeditions, ships stopped at various sites in the Atlantic ocean and gathered the following:
#
# 1. (Small) Environmental measurements taken at many depths at each site.
# 2. (Large) Genomic sequnce data taken at a couple depths at each site.

# %% [markdown]
# In this notebook we sketch the following pipeline of analysis to gain insight into the microbial life present in the ocean, as evidenced from the sequenced samples, and how the microbial life relates to the environment:
#
# 1. Connect to Myria and ingest the datasets of extracted kmers.
# 2. Combine samples into a single relation for unified analysis. Normalize.
# 3. Compute **diversity measures** of each sample.
# 4. Compute **Bray-Curtis distances** between samples.
# 5. Pre-process and upload **environmental data**.
# 6. Link environmental data to the genomic samples via **interpolation**.
# 7. Exploratory analysis with t-SNE and degree distributions.
#
# The result of our pipeline feeds the visualizations hosted at our istcdemo screen.

# %% [markdown]
# # Establish Connection to Myria

# %%
from myria import *
import numpy
# %load_ext myria

# %%
connection = MyriaConnection(rest_url='http://node-109:8753', \
                             execution_url = 'http://node-111:8124')
MyriaRelation.DefaultConnection = connection

# %% [markdown]
# ## View Relations in Database

# %%
datasets = connection.datasets()
print len(datasets)
for d in datasets[0:8]:
    print d['relationKey']['relationName']
# Out:
# 426
# AboveNotBelow
# BC_complete
# BC_condensed
# BelowNotAbove
# EnvironmentalData
# GeotracesConversionBystation
# Kmer11_gc_content
# SampleToEnvironmental

# %% [markdown]
# # Insert kmer Datasets

# %% [markdown]
# The following directory contains the extracted 11-mers of all overlapped samples.

# %%
dir_parsed_11_ol = '/home/gridsan/groups/istcdata/datasets/ocean_metagenome/csv_data/parsed_11_cnt'
from os import listdir
from os.path import isfile, join
files_parsed_11_ol = [f for f in listdir(dir_parsed_11_ol) \
                      if isfile(join(dir_parsed_11_ol, f)) and f[-4:] == '.csv']

# %%
print len(files_parsed_11_ol)
#print join(dir_parsed_11_ol, files_parsed_11_ol[0])
# Out:
# 396

# %% [markdown]
# The following code inserts each sample as a separate relation in the database.

# %%
for f in files_parsed_11_ol:
    fpath = 'file://%s' % join(dir_parsed_11_ol, f)
    rname = 'kmercnt_11_forward_%s_ol' % f[:5]
    query = %myrial T = load("@fpath", csv(schema(kmer:string, cnt:int))); store(T, @rname);
    print '%s: %s' % (f, query.status)
    break # Comment this line to insert all datasets, not just the first one.
# Out:
# S0168_11_cnt.csv: SUCCESS

# %% [markdown]
# ## Union samples into one relation

# %% [markdown]
# The following code outlines a simple way of automatically union'ing together all the relations in Myria that match a regular expression. We used this technique alongside batching the union queries.

# %%
pattern = re.compile('^kmercnt_11_rc_(S\d\d\d\d)_ol$')
resultRelation = 'kmercnt_11_rc_ol'

counter = 0
s = ''
for d in datasets:
    rn = d['relationKey']['relationName']
    m = pattern.match(rn)
    if m:
        sid = m.group(1)
        if s == '': s = '{1} = scan({0}); R = [from {1} emit "{1}" as sampleid, kmer, cnt];\n'.format(rn, sid)
        else: s += '{1} = scan({0}); R = R + [from {1} emit "{1}" as sampleid, kmer, cnt];\n'.format(rn, sid)
s += 'store(R, %s);' % resultRelation
print s
# Uncomment these lines to execute the query
#query  = %myrial @s
#print 'Query {}: {}'.format(query.query_id, query.status)
# Out:
# S0001 = scan(kmercnt_11_rc_S0001_ol); R = [from S0001 emit "S0001" as sampleid, kmer, cnt];
# S0002 = scan(kmercnt_11_rc_S0002_ol); R = R + [from S0002 emit "S0002" as sampleid, kmer, cnt];
# S0003 = scan(kmercnt_11_rc_S0003_ol); R = R + [from S0003 emit "S0003" as sampleid, kmer, cnt];
# S0004 = scan(kmercnt_11_rc_S0004_ol); R = R + [from S0004 emit "S0004" as sampleid, kmer, cnt];
# S0005 = scan(kmercnt_11_rc_S0005_ol); R = R + [from S0005 emit "S0005" as sampleid, kmer, cnt];
# S0006 = scan(kmercnt_11_rc_S0006_ol); R = R + [from S0006 emit "S0006" as sampleid, kmer, cnt];
# S0008 = scan(kmercnt_11_rc_S0008_ol); R = R + [from S0008 emit "S0008" as sampleid, kmer, cnt];
# S0009 = scan(kmercnt_11_rc_S0009_ol); R = R + [from S0009 emit "S0009" as sampleid, kmer, cnt];
# S0010 = scan(kmercnt_11_rc_S0010_ol); R = R + [from S0010 emit "S0010" as sampleid, kmer, cnt];
# S0011 = scan(kmercnt_11_rc_S0011_ol); R = R + [from S0011 emit "S0011" as sampleid, kmer, cnt];
# S0012 = scan(kmercnt_11_rc_S0012_ol); R = R + [from S0012 emit "S0012" as sampleid, kmer, cnt];
# S0013 = scan(kmercnt_11_rc_S0013_ol); R = R + [from S0013 emit "S0013" as sampleid, kmer, cnt];
# S0015 = scan(kmercnt_11_rc_S0015_ol); R = R + [from S0015 emit "S0015" as sampleid, kmer, cnt];
# S0016 = scan(kmercnt_11_rc_S0016_ol); R = R + [from S0016 emit "S0016" as sampleid, kmer, cnt];
# S0017 = scan(kmercnt_11_rc_S0017_ol); R = R + [from S0017 emit "S0017" as sampleid, kmer, cnt];
# S0018 = scan(kmercnt_11_rc_S0018_ol); R = R + [from S0018 emit "S0018" as sampleid, kmer, cnt];
# S0019 = scan(kmercnt_11_rc_S0019_ol); R = R + [from S0019 emit "S0019" as sampleid, kmer, cnt];
# S0020 = scan(kmercnt_11_rc_S0020_ol); R = R + [from S0020 emit "S0020" as sampleid, kmer, cnt];
# S0021 = scan(kmercnt_11_rc_S0021_ol); R = R + [from S0021 emit "S0021" as sampleid, kmer, cnt];
# S0022 = scan(kmercnt_11_rc_S0022_ol); R = R + [from S0022 emit "S0022" as sampleid, kmer, cnt];
# S0023 = scan(kmercnt_11_rc_S0023_ol); R = R + [from S0023 emit "S0023" as sampleid, kmer, cnt];
# S0024 = scan(kmercnt_11_rc_S0024_ol); R = R + [from S0024 emit "S0024" as sampleid, kmer, cnt];
# S0025 = scan(kmercnt_11_rc_S0025_ol); R = R + [from S0025 emit "S0025" as sampleid, kmer, cnt];
# S0026 = scan(kmercnt_11_rc_S0026_ol); R = R + [from S0026 emit "S0026" as sampleid, kmer, cnt];
# S0027 = scan(kmercnt_11_rc_S0027_ol); R = R + [from S0027 emit "S0027" as sampleid, kmer, cnt];
# S0028 = scan(kmercnt_11_rc_S0028_ol); R = R + [from S0028 emit "S0028" as sampleid, kmer, cnt];
# S0029 = scan(kmercnt_11_rc_S0029_ol); R = R + [from S0029 emit "S0029" as sampleid, kmer, cnt];
# S0030 = scan(kmercnt_11_rc_S0030_ol); R = R + [from S0030 emit "S0030" as sampleid, kmer, cnt];
# S0031 = scan(kmercnt_11_rc_S0031_ol); R = R + [from S0031 emit "S0031" as sampleid, kmer, cnt];
# S0032 = scan(kmercnt_11_rc_S0032_ol); R = R + [from S0032 emit "S0032" as sampleid, kmer, cnt];
# S0033 = scan(kmercnt_11_rc_S0033_ol); R = R + [from S0033 emit "S0033" as sampleid, kmer, cnt];
# S0034 = scan(kmercnt_11_rc_S0034_ol); R = R + [from S0034 emit "S0034" as sampleid, kmer, cnt];
# S0035 = scan(kmercnt_11_rc_S0035_ol); R = R + [from S0035 emit "S0035" as sampleid, kmer, cnt];
# S0036 = scan(kmercnt_11_rc_S0036_ol); R = R + [from S0036 emit "S0036" as sampleid, kmer, cnt];
# S0037 = scan(kmercnt_11_rc_S0037_ol); R = R + [from S0037 emit "S0037" as sampleid, kmer, cnt];
# S0039 = scan(kmercnt_11_rc_S0039_ol); R = R + [from S0039 emit "S0039" as sampleid, kmer, cnt];
# S0040 = scan(kmercnt_11_rc_S0040_ol); R = R + [from S0040 emit "S0040" as sampleid, kmer, cnt];
# S0041 = scan(kmercnt_11_rc_S0041_ol); R = R + [from S0041 emit "S0041" as sampleid, kmer, cnt];
# S0042 = scan(kmercnt_11_rc_S0042_ol); R = R + [from S0042 emit "S0042" as sampleid, kmer, cnt];
# S0043 = scan(kmercnt_11_rc_S0043_ol); R = R + [from S0043 emit "S0043" as sampleid, kmer, cnt];
# S0045 = scan(kmercnt_11_rc_S0045_ol); R = R + [from S0045 emit "S0045" as sampleid, kmer, cnt];
# S0046 = scan(kmercnt_11_rc_S0046_ol); R = R + [from S0046 emit "S0046" as sampleid, kmer, cnt];
# S0047 = scan(kmercnt_11_rc_S0047_ol); R = R + [from S0047 emit "S0047" as sampleid, kmer, cnt];
# S0048 = scan(kmercnt_11_rc_S0048_ol); R = R + [from S0048 emit "S0048" as sampleid, kmer, cnt];
# S0049 = scan(kmercnt_11_rc_S0049_ol); R = R + [from S0049 emit "S0049" as sampleid, kmer, cnt];
# S0050 = scan(kmercnt_11_rc_S0050_ol); R = R + [from S0050 emit "S0050" as sampleid, kmer, cnt];
# S0051 = scan(kmercnt_11_rc_S0051_ol); R = R + [from S0051 emit "S0051" as sampleid, kmer, cnt];
# S0052 = scan(kmercnt_11_rc_S0052_ol); R = R + [from S0052 emit "S0052" as sampleid, kmer, cnt];
# S0053 = scan(kmercnt_11_rc_S0053_ol); R = R + [from S0053 emit "S0053" as sampleid, kmer, cnt];
# S0054 = scan(kmercnt_11_rc_S0054_ol); R = R + [from S0054 emit "S0054" as sampleid, kmer, cnt];
# S0055 = scan(kmercnt_11_rc_S0055_ol); R = R + [from S0055 emit "S0055" as sampleid, kmer, cnt];
# S0057 = scan(kmercnt_11_rc_S0057_ol); R = R + [from S0057 emit "S0057" as sampleid, kmer, cnt];
# S0058 = scan(kmercnt_11_rc_S0058_ol); R = R + [from S0058 emit "S0058" as sampleid, kmer, cnt];
# S0059 = scan(kmercnt_11_rc_S0059_ol); R = R + [from S0059 emit "S0059" as sampleid, kmer, cnt];
# S0060 = scan(kmercnt_11_rc_S0060_ol); R = R + [from S0060 emit "S0060" as sampleid, kmer, cnt];
# S0061 = scan(kmercnt_11_rc_S0061_ol); R = R + [from S0061 emit "S0061" as sampleid, kmer, cnt];
# S0062 = scan(kmercnt_11_rc_S0062_ol); R = R + [from S0062 emit "S0062" as sampleid, kmer, cnt];
# S0063 = scan(kmercnt_11_rc_S0063_ol); R = R + [from S0063 emit "S0063" as sampleid, kmer, cnt];
# S0064 = scan(kmercnt_11_rc_S0064_ol); R = R + [from S0064 emit "S0064" as sampleid, kmer, cnt];
# S0065 = scan(kmercnt_11_rc_S0065_ol); R = R + [from S0065 emit "S0065" as sampleid, kmer, cnt];
# S0066 = scan(kmercnt_11_rc_S0066_ol); R = R + [from S0066 emit "S0066" as sampleid, kmer, cnt];
# S0067 = scan(kmercnt_11_rc_S0067_ol); R = R + [from S0067 emit "S0067" as sampleid, kmer, cnt];
# S0068 = scan(kmercnt_11_rc_S0068_ol); R = R + [from S0068 emit "S0068" as sampleid, kmer, cnt];
# S0069 = scan(kmercnt_11_rc_S0069_ol); R = R + [from S0069 emit "S0069" as sampleid, kmer, cnt];
# S0070 = scan(kmercnt_11_rc_S0070_ol); R = R + [from S0070 emit "S0070" as sampleid, kmer, cnt];
# S0071 = scan(kmercnt_11_rc_S0071_ol); R = R + [from S0071 emit "S0071" as sampleid, kmer, cnt];
# S0072 = scan(kmercnt_11_rc_S0072_ol); R = R + [from S0072 emit "S0072" as sampleid, kmer, cnt];
# S0073 = scan(kmercnt_11_rc_S0073_ol); R = R + [from S0073 emit "S0073" as sampleid, kmer, cnt];
# S0074 = scan(kmercnt_11_rc_S0074_ol); R = R + [from S0074 emit "S0074" as sampleid, kmer, cnt];
# S0075 = scan(kmercnt_11_rc_S0075_ol); R = R + [from S0075 emit "S0075" as sampleid, kmer, cnt];
# S0076 = scan(kmercnt_11_rc_S0076_ol); R = R + [from S0076 emit "S0076" as sampleid, kmer, cnt];
# S0077 = scan(kmercnt_11_rc_S0077_ol); R = R + [from S0077 emit "S0077" as sampleid, kmer, cnt];
# S0078 = scan(kmercnt_11_rc_S0078_ol); R = R + [from S0078 emit "S0078" as sampleid, kmer, cnt];
# S0079 = scan(kmercnt_11_rc_S0079_ol); R = R + [from S0079 emit "S0079" as sampleid, kmer, cnt];
# S0080 = scan(kmercnt_11_rc_S0080_ol); R = R + [from S0080 emit "S0080" as sampleid, kmer, cnt];
# S0081 = scan(kmercnt_11_rc_S0081_ol); R = R + [from S0081 emit "S0081" as sampleid, kmer, cnt];
# S0082 = scan(kmercnt_11_rc_S0082_ol); R = R + [from S0082 emit "S0082" as sampleid, kmer, cnt];
# S0083 = scan(kmercnt_11_rc_S0083_ol); R = R + [from S0083 emit "S0083" as sampleid, kmer, cnt];
# S0084 = scan(kmercnt_11_rc_S0084_ol); R = R + [from S0084 emit "S0084" as sampleid, kmer, cnt];
# S0085 = scan(kmercnt_11_rc_S0085_ol); R = R + [from S0085 emit "S0085" as sampleid, kmer, cnt];
# S0086 = scan(kmercnt_11_rc_S0086_ol); R = R + [from S0086 emit "S0086" as sampleid, kmer, cnt];
# S0087 = scan(kmercnt_11_rc_S0087_ol); R = R + [from S0087 emit "S0087" as sampleid, kmer, cnt];
# S0088 = scan(kmercnt_11_rc_S0088_ol); R = R + [from S0088 emit "S0088" as sampleid, kmer, cnt];
# S0089 = scan(kmercnt_11_rc_S0089_ol); R = R + [from S0089 emit "S0089" as sampleid, kmer, cnt];
# S0090 = scan(kmercnt_11_rc_S0090_ol); R = R + [from S0090 emit "S0090" as sampleid, kmer, cnt];
# S0091 = scan(kmercnt_11_rc_S0091_ol); R = R + [from S0091 emit "S0091" as sampleid, kmer, cnt];
# S0092 = scan(kmercnt_11_rc_S0092_ol); R = R + [from S0092 emit "S0092" as sampleid, kmer, cnt];
# S0093 = scan(kmercnt_11_rc_S0093_ol); R = R + [from S0093 emit "S0093" as sampleid, kmer, cnt];
# S0094 = scan(kmercnt_11_rc_S0094_ol); R = R + [from S0094 emit "S0094" as sampleid, kmer, cnt];
# S0095 = scan(kmercnt_11_rc_S0095_ol); R = R + [from S0095 emit "S0095" as sampleid, kmer, cnt];
# S0096 = scan(kmercnt_11_rc_S0096_ol); R = R + [from S0096 emit "S0096" as sampleid, kmer, cnt];
# S0097 = scan(kmercnt_11_rc_S0097_ol); R = R + [from S0097 emit "S0097" as sampleid, kmer, cnt];
# S0098 = scan(kmercnt_11_rc_S0098_ol); R = R + [from S0098 emit "S0098" as sampleid, kmer, cnt];
# S0099 = scan(kmercnt_11_rc_S0099_ol); R = R + [from S0099 emit "S0099" as sampleid, kmer, cnt];
# S0100 = scan(kmercnt_11_rc_S0100_ol); R = R + [from S0100 emit "S0100" as sampleid, kmer, cnt];
# S0101 = scan(kmercnt_11_rc_S0101_ol); R = R + [from S0101 emit "S0101" as sampleid, kmer, cnt];
# S0102 = scan(kmercnt_11_rc_S0102_ol); R = R + [from S0102 emit "S0102" as sampleid, kmer, cnt];
# S0103 = scan(kmercnt_11_rc_S0103_ol); R = R + [from S0103 emit "S0103" as sampleid, kmer, cnt];
# S0104 = scan(kmercnt_11_rc_S0104_ol); R = R + [from S0104 emit "S0104" as sampleid, kmer, cnt];
# S0105 = scan(kmercnt_11_rc_S0105_ol); R = R + [from S0105 emit "S0105" as sampleid, kmer, cnt];
# S0106 = scan(kmercnt_11_rc_S0106_ol); R = R + [from S0106 emit "S0106" as sampleid, kmer, cnt];
# S0107 = scan(kmercnt_11_rc_S0107_ol); R = R + [from S0107 emit "S0107" as sampleid, kmer, cnt];
# S0108 = scan(kmercnt_11_rc_S0108_ol); R = R + [from S0108 emit "S0108" as sampleid, kmer, cnt];
# S0109 = scan(kmercnt_11_rc_S0109_ol); R = R + [from S0109 emit "S0109" as sampleid, kmer, cnt];
# S0110 = scan(kmercnt_11_rc_S0110_ol); R = R + [from S0110 emit "S0110" as sampleid, kmer, cnt];
# S0111 = scan(kmercnt_11_rc_S0111_ol); R = R + [from S0111 emit "S0111" as sampleid, kmer, cnt];
# S0112 = scan(kmercnt_11_rc_S0112_ol); R = R + [from S0112 emit "S0112" as sampleid, kmer, cnt];
# S0114 = scan(kmercnt_11_rc_S0114_ol); R = R + [from S0114 emit "S0114" as sampleid, kmer, cnt];
# S0115 = scan(kmercnt_11_rc_S0115_ol); R = R + [from S0115 emit "S0115" as sampleid, kmer, cnt];
# S0116 = scan(kmercnt_11_rc_S0116_ol); R = R + [from S0116 emit "S0116" as sampleid, kmer, cnt];
# S0117 = scan(kmercnt_11_rc_S0117_ol); R = R + [from S0117 emit "S0117" as sampleid, kmer, cnt];
# S0118 = scan(kmercnt_11_rc_S0118_ol); R = R + [from S0118 emit "S0118" as sampleid, kmer, cnt];
# S0119 = scan(kmercnt_11_rc_S0119_ol); R = R + [from S0119 emit "S0119" as sampleid, kmer, cnt];
# S0120 = scan(kmercnt_11_rc_S0120_ol); R = R + [from S0120 emit "S0120" as sampleid, kmer, cnt];
# S0122 = scan(kmercnt_11_rc_S0122_ol); R = R + [from S0122 emit "S0122" as sampleid, kmer, cnt];
# S0123 = scan(kmercnt_11_rc_S0123_ol); R = R + [from S0123 emit "S0123" as sampleid, kmer, cnt];
# S0124 = scan(kmercnt_11_rc_S0124_ol); R = R + [from S0124 emit "S0124" as sampleid, kmer, cnt];
# S0125 = scan(kmercnt_11_rc_S0125_ol); R = R + [from S0125 emit "S0125" as sampleid, kmer, cnt];
# S0126 = scan(kmercnt_11_rc_S0126_ol); R = R + [from S0126 emit "S0126" as sampleid, kmer, cnt];
# S0127 = scan(kmercnt_11_rc_S0127_ol); R = R + [from S0127 emit "S0127" as sampleid, kmer, cnt];
# S0128 = scan(kmercnt_11_rc_S0128_ol); R = R + [from S0128 emit "S0128" as sampleid, kmer, cnt];
# S0129 = scan(kmercnt_11_rc_S0129_ol); R = R + [from S0129 emit "S0129" as sampleid, kmer, cnt];
# S0130 = scan(kmercnt_11_rc_S0130_ol); R = R + [from S0130 emit "S0130" as sampleid, kmer, cnt];
# S0131 = scan(kmercnt_11_rc_S0131_ol); R = R + [from S0131 emit "S0131" as sampleid, kmer, cnt];
# S0132 = scan(kmercnt_11_rc_S0132_ol); R = R + [from S0132 emit "S0132" as sampleid, kmer, cnt];
# S0133 = scan(kmercnt_11_rc_S0133_ol); R = R + [from S0133 emit "S0133" as sampleid, kmer, cnt];
# S0134 = scan(kmercnt_11_rc_S0134_ol); R = R + [from S0134 emit "S0134" as sampleid, kmer, cnt];
# S0135 = scan(kmercnt_11_rc_S0135_ol); R = R + [from S0135 emit "S0135" as sampleid, kmer, cnt];
# S0136 = scan(kmercnt_11_rc_S0136_ol); R = R + [from S0136 emit "S0136" as sampleid, kmer, cnt];
# S0137 = scan(kmercnt_11_rc_S0137_ol); R = R + [from S0137 emit "S0137" as sampleid, kmer, cnt];
# S0138 = scan(kmercnt_11_rc_S0138_ol); R = R + [from S0138 emit "S0138" as sampleid, kmer, cnt];
# S0139 = scan(kmercnt_11_rc_S0139_ol); R = R + [from S0139 emit "S0139" as sampleid, kmer, cnt];
# S0140 = scan(kmercnt_11_rc_S0140_ol); R = R + [from S0140 emit "S0140" as sampleid, kmer, cnt];
# S0141 = scan(kmercnt_11_rc_S0141_ol); R = R + [from S0141 emit "S0141" as sampleid, kmer, cnt];
# S0142 = scan(kmercnt_11_rc_S0142_ol); R = R + [from S0142 emit "S0142" as sampleid, kmer, cnt];
# S0143 = scan(kmercnt_11_rc_S0143_ol); R = R + [from S0143 emit "S0143" as sampleid, kmer, cnt];
# S0144 = scan(kmercnt_11_rc_S0144_ol); R = R + [from S0144 emit "S0144" as sampleid, kmer, cnt];
# S0145 = scan(kmercnt_11_rc_S0145_ol); R = R + [from S0145 emit "S0145" as sampleid, kmer, cnt];
# S0149 = scan(kmercnt_11_rc_S0149_ol); R = R + [from S0149 emit "S0149" as sampleid, kmer, cnt];
# S0150 = scan(kmercnt_11_rc_S0150_ol); R = R + [from S0150 emit "S0150" as sampleid, kmer, cnt];
# S0151 = scan(kmercnt_11_rc_S0151_ol); R = R + [from S0151 emit "S0151" as sampleid, kmer, cnt];
# S0153 = scan(kmercnt_11_rc_S0153_ol); R = R + [from S0153 emit "S0153" as sampleid, kmer, cnt];
# S0154 = scan(kmercnt_11_rc_S0154_ol); R = R + [from S0154 emit "S0154" as sampleid, kmer, cnt];
# S0155 = scan(kmercnt_11_rc_S0155_ol); R = R + [from S0155 emit "S0155" as sampleid, kmer, cnt];
# S0156 = scan(kmercnt_11_rc_S0156_ol); R = R + [from S0156 emit "S0156" as sampleid, kmer, cnt];
# S0157 = scan(kmercnt_11_rc_S0157_ol); R = R + [from S0157 emit "S0157" as sampleid, kmer, cnt];
# S0158 = scan(kmercnt_11_rc_S0158_ol); R = R + [from S0158 emit "S0158" as sampleid, kmer, cnt];
# S0159 = scan(kmercnt_11_rc_S0159_ol); R = R + [from S0159 emit "S0159" as sampleid, kmer, cnt];
# S0161 = scan(kmercnt_11_rc_S0161_ol); R = R + [from S0161 emit "S0161" as sampleid, kmer, cnt];
# S0164 = scan(kmercnt_11_rc_S0164_ol); R = R + [from S0164 emit "S0164" as sampleid, kmer, cnt];
# S0165 = scan(kmercnt_11_rc_S0165_ol); R = R + [from S0165 emit "S0165" as sampleid, kmer, cnt];
# S0166 = scan(kmercnt_11_rc_S0166_ol); R = R + [from S0166 emit "S0166" as sampleid, kmer, cnt];
# S0167 = scan(kmercnt_11_rc_S0167_ol); R = R + [from S0167 emit "S0167" as sampleid, kmer, cnt];
# S0168 = scan(kmercnt_11_rc_S0168_ol); R = R + [from S0168 emit "S0168" as sampleid, kmer, cnt];
# S0169 = scan(kmercnt_11_rc_S0169_ol); R = R + [from S0169 emit "S0169" as sampleid, kmer, cnt];
# S0171 = scan(kmercnt_11_rc_S0171_ol); R = R + [from S0171 emit "S0171" as sampleid, kmer, cnt];
# S0172 = scan(kmercnt_11_rc_S0172_ol); R = R + [from S0172 emit "S0172" as sampleid, kmer, cnt];
# S0173 = scan(kmercnt_11_rc_S0173_ol); R = R + [from S0173 emit "S0173" as sampleid, kmer, cnt];
# S0174 = scan(kmercnt_11_rc_S0174_ol); R = R + [from S0174 emit "S0174" as sampleid, kmer, cnt];
# S0175 = scan(kmercnt_11_rc_S0175_ol); R = R + [from S0175 emit "S0175" as sampleid, kmer, cnt];
# S0177 = scan(kmercnt_11_rc_S0177_ol); R = R + [from S0177 emit "S0177" as sampleid, kmer, cnt];
# S0178 = scan(kmercnt_11_rc_S0178_ol); R = R + [from S0178 emit "S0178" as sampleid, kmer, cnt];
# S0179 = scan(kmercnt_11_rc_S0179_ol); R = R + [from S0179 emit "S0179" as sampleid, kmer, cnt];
# S0180 = scan(kmercnt_11_rc_S0180_ol); R = R + [from S0180 emit "S0180" as sampleid, kmer, cnt];
# S0181 = scan(kmercnt_11_rc_S0181_ol); R = R + [from S0181 emit "S0181" as sampleid, kmer, cnt];
# S0182 = scan(kmercnt_11_rc_S0182_ol); R = R + [from S0182 emit "S0182" as sampleid, kmer, cnt];
# S0183 = scan(kmercnt_11_rc_S0183_ol); R = R + [from S0183 emit "S0183" as sampleid, kmer, cnt];
# S0184 = scan(kmercnt_11_rc_S0184_ol); R = R + [from S0184 emit "S0184" as sampleid, kmer, cnt];
# S0185 = scan(kmercnt_11_rc_S0185_ol); R = R + [from S0185 emit "S0185" as sampleid, kmer, cnt];
# S0186 = scan(kmercnt_11_rc_S0186_ol); R = R + [from S0186 emit "S0186" as sampleid, kmer, cnt];
# S0187 = scan(kmercnt_11_rc_S0187_ol); R = R + [from S0187 emit "S0187" as sampleid, kmer, cnt];
# S0188 = scan(kmercnt_11_rc_S0188_ol); R = R + [from S0188 emit "S0188" as sampleid, kmer, cnt];
# S0189 = scan(kmercnt_11_rc_S0189_ol); R = R + [from S0189 emit "S0189" as sampleid, kmer, cnt];
# S0190 = scan(kmercnt_11_rc_S0190_ol); R = R + [from S0190 emit "S0190" as sampleid, kmer, cnt];
# S0191 = scan(kmercnt_11_rc_S0191_ol); R = R + [from S0191 emit "S0191" as sampleid, kmer, cnt];
# S0192 = scan(kmercnt_11_rc_S0192_ol); R = R + [from S0192 emit "S0192" as sampleid, kmer, cnt];
# S0193 = scan(kmercnt_11_rc_S0193_ol); R = R + [from S0193 emit "S0193" as sampleid, kmer, cnt];
# S0195 = scan(kmercnt_11_rc_S0195_ol); R = R + [from S0195 emit "S0195" as sampleid, kmer, cnt];
# S0196 = scan(kmercnt_11_rc_S0196_ol); R = R + [from S0196 emit "S0196" as sampleid, kmer, cnt];
# S0197 = scan(kmercnt_11_rc_S0197_ol); R = R + [from S0197 emit "S0197" as sampleid, kmer, cnt];
# S0198 = scan(kmercnt_11_rc_S0198_ol); R = R + [from S0198 emit "S0198" as sampleid, kmer, cnt];
# S0199 = scan(kmercnt_11_rc_S0199_ol); R = R + [from S0199 emit "S0199" as sampleid, kmer, cnt];
# S0200 = scan(kmercnt_11_rc_S0200_ol); R = R + [from S0200 emit "S0200" as sampleid, kmer, cnt];
# S0201 = scan(kmercnt_11_rc_S0201_ol); R = R + [from S0201 emit "S0201" as sampleid, kmer, cnt];
# S0202 = scan(kmercnt_11_rc_S0202_ol); R = R + [from S0202 emit "S0202" as sampleid, kmer, cnt];
# S0203 = scan(kmercnt_11_rc_S0203_ol); R = R + [from S0203 emit "S0203" as sampleid, kmer, cnt];
# S0204 = scan(kmercnt_11_rc_S0204_ol); R = R + [from S0204 emit "S0204" as sampleid, kmer, cnt];
# S0205 = scan(kmercnt_11_rc_S0205_ol); R = R + [from S0205 emit "S0205" as sampleid, kmer, cnt];
# S0206 = scan(kmercnt_11_rc_S0206_ol); R = R + [from S0206 emit "S0206" as sampleid, kmer, cnt];
# S0207 = scan(kmercnt_11_rc_S0207_ol); R = R + [from S0207 emit "S0207" as sampleid, kmer, cnt];
# S0209 = scan(kmercnt_11_rc_S0209_ol); R = R + [from S0209 emit "S0209" as sampleid, kmer, cnt];
# S0211 = scan(kmercnt_11_rc_S0211_ol); R = R + [from S0211 emit "S0211" as sampleid, kmer, cnt];
# S0212 = scan(kmercnt_11_rc_S0212_ol); R = R + [from S0212 emit "S0212" as sampleid, kmer, cnt];
# S0213 = scan(kmercnt_11_rc_S0213_ol); R = R + [from S0213 emit "S0213" as sampleid, kmer, cnt];
# S0214 = scan(kmercnt_11_rc_S0214_ol); R = R + [from S0214 emit "S0214" as sampleid, kmer, cnt];
# S0215 = scan(kmercnt_11_rc_S0215_ol); R = R + [from S0215 emit "S0215" as sampleid, kmer, cnt];
# S0216 = scan(kmercnt_11_rc_S0216_ol); R = R + [from S0216 emit "S0216" as sampleid, kmer, cnt];
# S0217 = scan(kmercnt_11_rc_S0217_ol); R = R + [from S0217 emit "S0217" as sampleid, kmer, cnt];
# S0218 = scan(kmercnt_11_rc_S0218_ol); R = R + [from S0218 emit "S0218" as sampleid, kmer, cnt];
# S0219 = scan(kmercnt_11_rc_S0219_ol); R = R + [from S0219 emit "S0219" as sampleid, kmer, cnt];
# S0220 = scan(kmercnt_11_rc_S0220_ol); R = R + [from S0220 emit "S0220" as sampleid, kmer, cnt];
# S0221 = scan(kmercnt_11_rc_S0221_ol); R = R + [from S0221 emit "S0221" as sampleid, kmer, cnt];
# S0222 = scan(kmercnt_11_rc_S0222_ol); R = R + [from S0222 emit "S0222" as sampleid, kmer, cnt];
# S0223 = scan(kmercnt_11_rc_S0223_ol); R = R + [from S0223 emit "S0223" as sampleid, kmer, cnt];
# S0224 = scan(kmercnt_11_rc_S0224_ol); R = R + [from S0224 emit "S0224" as sampleid, kmer, cnt];
# S0225 = scan(kmercnt_11_rc_S0225_ol); R = R + [from S0225 emit "S0225" as sampleid, kmer, cnt];
# S0226 = scan(kmercnt_11_rc_S0226_ol); R = R + [from S0226 emit "S0226" as sampleid, kmer, cnt];
# S0227 = scan(kmercnt_11_rc_S0227_ol); R = R + [from S0227 emit "S0227" as sampleid, kmer, cnt];
# S0228 = scan(kmercnt_11_rc_S0228_ol); R = R + [from S0228 emit "S0228" as sampleid, kmer, cnt];
# S0229 = scan(kmercnt_11_rc_S0229_ol); R = R + [from S0229 emit "S0229" as sampleid, kmer, cnt];
# S0231 = scan(kmercnt_11_rc_S0231_ol); R = R + [from S0231 emit "S0231" as sampleid, kmer, cnt];
# S0232 = scan(kmercnt_11_rc_S0232_ol); R = R + [from S0232 emit "S0232" as sampleid, kmer, cnt];
# S0233 = scan(kmercnt_11_rc_S0233_ol); R = R + [from S0233 emit "S0233" as sampleid, kmer, cnt];
# S0234 = scan(kmercnt_11_rc_S0234_ol); R = R + [from S0234 emit "S0234" as sampleid, kmer, cnt];
# S0235 = scan(kmercnt_11_rc_S0235_ol); R = R + [from S0235 emit "S0235" as sampleid, kmer, cnt];
# S0236 = scan(kmercnt_11_rc_S0236_ol); R = R + [from S0236 emit "S0236" as sampleid, kmer, cnt];
# S0237 = scan(kmercnt_11_rc_S0237_ol); R = R + [from S0237 emit "S0237" as sampleid, kmer, cnt];
# S0238 = scan(kmercnt_11_rc_S0238_ol); R = R + [from S0238 emit "S0238" as sampleid, kmer, cnt];
# S0239 = scan(kmercnt_11_rc_S0239_ol); R = R + [from S0239 emit "S0239" as sampleid, kmer, cnt];
# S0240 = scan(kmercnt_11_rc_S0240_ol); R = R + [from S0240 emit "S0240" as sampleid, kmer, cnt];
# S0241 = scan(kmercnt_11_rc_S0241_ol); R = R + [from S0241 emit "S0241" as sampleid, kmer, cnt];
# S0242 = scan(kmercnt_11_rc_S0242_ol); R = R + [from S0242 emit "S0242" as sampleid, kmer, cnt];
# S0243 = scan(kmercnt_11_rc_S0243_ol); R = R + [from S0243 emit "S0243" as sampleid, kmer, cnt];
# S0244 = scan(kmercnt_11_rc_S0244_ol); R = R + [from S0244 emit "S0244" as sampleid, kmer, cnt];
# S0245 = scan(kmercnt_11_rc_S0245_ol); R = R + [from S0245 emit "S0245" as sampleid, kmer, cnt];
# S0246 = scan(kmercnt_11_rc_S0246_ol); R = R + [from S0246 emit "S0246" as sampleid, kmer, cnt];
# S0247 = scan(kmercnt_11_rc_S0247_ol); R = R + [from S0247 emit "S0247" as sampleid, kmer, cnt];
# S0248 = scan(kmercnt_11_rc_S0248_ol); R = R + [from S0248 emit "S0248" as sampleid, kmer, cnt];
# S0249 = scan(kmercnt_11_rc_S0249_ol); R = R + [from S0249 emit "S0249" as sampleid, kmer, cnt];
# S0250 = scan(kmercnt_11_rc_S0250_ol); R = R + [from S0250 emit "S0250" as sampleid, kmer, cnt];
# S0251 = scan(kmercnt_11_rc_S0251_ol); R = R + [from S0251 emit "S0251" as sampleid, kmer, cnt];
# S0252 = scan(kmercnt_11_rc_S0252_ol); R = R + [from S0252 emit "S0252" as sampleid, kmer, cnt];
# S0253 = scan(kmercnt_11_rc_S0253_ol); R = R + [from S0253 emit "S0253" as sampleid, kmer, cnt];
# S0254 = scan(kmercnt_11_rc_S0254_ol); R = R + [from S0254 emit "S0254" as sampleid, kmer, cnt];
# S0255 = scan(kmercnt_11_rc_S0255_ol); R = R + [from S0255 emit "S0255" as sampleid, kmer, cnt];
# S0256 = scan(kmercnt_11_rc_S0256_ol); R = R + [from S0256 emit "S0256" as sampleid, kmer, cnt];
# S0257 = scan(kmercnt_11_rc_S0257_ol); R = R + [from S0257 emit "S0257" as sampleid, kmer, cnt];
# S0258 = scan(kmercnt_11_rc_S0258_ol); R = R + [from S0258 emit "S0258" as sampleid, kmer, cnt];
# S0259 = scan(kmercnt_11_rc_S0259_ol); R = R + [from S0259 emit "S0259" as sampleid, kmer, cnt];
# S0260 = scan(kmercnt_11_rc_S0260_ol); R = R + [from S0260 emit "S0260" as sampleid, kmer, cnt];
# S0261 = scan(kmercnt_11_rc_S0261_ol); R = R + [from S0261 emit "S0261" as sampleid, kmer, cnt];
# S0262 = scan(kmercnt_11_rc_S0262_ol); R = R + [from S0262 emit "S0262" as sampleid, kmer, cnt];
# S0263 = scan(kmercnt_11_rc_S0263_ol); R = R + [from S0263 emit "S0263" as sampleid, kmer, cnt];
# S0264 = scan(kmercnt_11_rc_S0264_ol); R = R + [from S0264 emit "S0264" as sampleid, kmer, cnt];
# S0265 = scan(kmercnt_11_rc_S0265_ol); R = R + [from S0265 emit "S0265" as sampleid, kmer, cnt];
# S0266 = scan(kmercnt_11_rc_S0266_ol); R = R + [from S0266 emit "S0266" as sampleid, kmer, cnt];
# S0267 = scan(kmercnt_11_rc_S0267_ol); R = R + [from S0267 emit "S0267" as sampleid, kmer, cnt];
# S0268 = scan(kmercnt_11_rc_S0268_ol); R = R + [from S0268 emit "S0268" as sampleid, kmer, cnt];
# S0269 = scan(kmercnt_11_rc_S0269_ol); R = R + [from S0269 emit "S0269" as sampleid, kmer, cnt];
# S0270 = scan(kmercnt_11_rc_S0270_ol); R = R + [from S0270 emit "S0270" as sampleid, kmer, cnt];
# S0271 = scan(kmercnt_11_rc_S0271_ol); R = R + [from S0271 emit "S0271" as sampleid, kmer, cnt];
# S0272 = scan(kmercnt_11_rc_S0272_ol); R = R + [from S0272 emit "S0272" as sampleid, kmer, cnt];
# S0273 = scan(kmercnt_11_rc_S0273_ol); R = R + [from S0273 emit "S0273" as sampleid, kmer, cnt];
# S0274 = scan(kmercnt_11_rc_S0274_ol); R = R + [from S0274 emit "S0274" as sampleid, kmer, cnt];
# S0275 = scan(kmercnt_11_rc_S0275_ol); R = R + [from S0275 emit "S0275" as sampleid, kmer, cnt];
# S0276 = scan(kmercnt_11_rc_S0276_ol); R = R + [from S0276 emit "S0276" as sampleid, kmer, cnt];
# S0277 = scan(kmercnt_11_rc_S0277_ol); R = R + [from S0277 emit "S0277" as sampleid, kmer, cnt];
# S0278 = scan(kmercnt_11_rc_S0278_ol); R = R + [from S0278 emit "S0278" as sampleid, kmer, cnt];
# S0279 = scan(kmercnt_11_rc_S0279_ol); R = R + [from S0279 emit "S0279" as sampleid, kmer, cnt];
# S0280 = scan(kmercnt_11_rc_S0280_ol); R = R + [from S0280 emit "S0280" as sampleid, kmer, cnt];
# S0281 = scan(kmercnt_11_rc_S0281_ol); R = R + [from S0281 emit "S0281" as sampleid, kmer, cnt];
# S0282 = scan(kmercnt_11_rc_S0282_ol); R = R + [from S0282 emit "S0282" as sampleid, kmer, cnt];
# S0283 = scan(kmercnt_11_rc_S0283_ol); R = R + [from S0283 emit "S0283" as sampleid, kmer, cnt];
# S0284 = scan(kmercnt_11_rc_S0284_ol); R = R + [from S0284 emit "S0284" as sampleid, kmer, cnt];
# S0285 = scan(kmercnt_11_rc_S0285_ol); R = R + [from S0285 emit "S0285" as sampleid, kmer, cnt];
# S0286 = scan(kmercnt_11_rc_S0286_ol); R = R + [from S0286 emit "S0286" as sampleid, kmer, cnt];
# S0289 = scan(kmercnt_11_rc_S0289_ol); R = R + [from S0289 emit "S0289" as sampleid, kmer, cnt];
# S0290 = scan(kmercnt_11_rc_S0290_ol); R = R + [from S0290 emit "S0290" as sampleid, kmer, cnt];
# S0291 = scan(kmercnt_11_rc_S0291_ol); R = R + [from S0291 emit "S0291" as sampleid, kmer, cnt];
# S0292 = scan(kmercnt_11_rc_S0292_ol); R = R + [from S0292 emit "S0292" as sampleid, kmer, cnt];
# S0293 = scan(kmercnt_11_rc_S0293_ol); R = R + [from S0293 emit "S0293" as sampleid, kmer, cnt];
# S0294 = scan(kmercnt_11_rc_S0294_ol); R = R + [from S0294 emit "S0294" as sampleid, kmer, cnt];
# S0295 = scan(kmercnt_11_rc_S0295_ol); R = R + [from S0295 emit "S0295" as sampleid, kmer, cnt];
# S0296 = scan(kmercnt_11_rc_S0296_ol); R = R + [from S0296 emit "S0296" as sampleid, kmer, cnt];
# S0297 = scan(kmercnt_11_rc_S0297_ol); R = R + [from S0297 emit "S0297" as sampleid, kmer, cnt];
# S0298 = scan(kmercnt_11_rc_S0298_ol); R = R + [from S0298 emit "S0298" as sampleid, kmer, cnt];
# S0299 = scan(kmercnt_11_rc_S0299_ol); R = R + [from S0299 emit "S0299" as sampleid, kmer, cnt];
# S0300 = scan(kmercnt_11_rc_S0300_ol); R = R + [from S0300 emit "S0300" as sampleid, kmer, cnt];
# S0301 = scan(kmercnt_11_rc_S0301_ol); R = R + [from S0301 emit "S0301" as sampleid, kmer, cnt];
# S0302 = scan(kmercnt_11_rc_S0302_ol); R = R + [from S0302 emit "S0302" as sampleid, kmer, cnt];
# S0303 = scan(kmercnt_11_rc_S0303_ol); R = R + [from S0303 emit "S0303" as sampleid, kmer, cnt];
# S0304 = scan(kmercnt_11_rc_S0304_ol); R = R + [from S0304 emit "S0304" as sampleid, kmer, cnt];
# S0305 = scan(kmercnt_11_rc_S0305_ol); R = R + [from S0305 emit "S0305" as sampleid, kmer, cnt];
# S0306 = scan(kmercnt_11_rc_S0306_ol); R = R + [from S0306 emit "S0306" as sampleid, kmer, cnt];
# S0307 = scan(kmercnt_11_rc_S0307_ol); R = R + [from S0307 emit "S0307" as sampleid, kmer, cnt];
# S0308 = scan(kmercnt_11_rc_S0308_ol); R = R + [from S0308 emit "S0308" as sampleid, kmer, cnt];
# S0309 = scan(kmercnt_11_rc_S0309_ol); R = R + [from S0309 emit "S0309" as sampleid, kmer, cnt];
# S0311 = scan(kmercnt_11_rc_S0311_ol); R = R + [from S0311 emit "S0311" as sampleid, kmer, cnt];
# S0312 = scan(kmercnt_11_rc_S0312_ol); R = R + [from S0312 emit "S0312" as sampleid, kmer, cnt];
# S0313 = scan(kmercnt_11_rc_S0313_ol); R = R + [from S0313 emit "S0313" as sampleid, kmer, cnt];
# S0314 = scan(kmercnt_11_rc_S0314_ol); R = R + [from S0314 emit "S0314" as sampleid, kmer, cnt];
# S0315 = scan(kmercnt_11_rc_S0315_ol); R = R + [from S0315 emit "S0315" as sampleid, kmer, cnt];
# S0316 = scan(kmercnt_11_rc_S0316_ol); R = R + [from S0316 emit "S0316" as sampleid, kmer, cnt];
# S0317 = scan(kmercnt_11_rc_S0317_ol); R = R + [from S0317 emit "S0317" as sampleid, kmer, cnt];
# S0318 = scan(kmercnt_11_rc_S0318_ol); R = R + [from S0318 emit "S0318" as sampleid, kmer, cnt];
# S0319 = scan(kmercnt_11_rc_S0319_ol); R = R + [from S0319 emit "S0319" as sampleid, kmer, cnt];
# S0321 = scan(kmercnt_11_rc_S0321_ol); R = R + [from S0321 emit "S0321" as sampleid, kmer, cnt];
# S0322 = scan(kmercnt_11_rc_S0322_ol); R = R + [from S0322 emit "S0322" as sampleid, kmer, cnt];
# S0323 = scan(kmercnt_11_rc_S0323_ol); R = R + [from S0323 emit "S0323" as sampleid, kmer, cnt];
# S0324 = scan(kmercnt_11_rc_S0324_ol); R = R + [from S0324 emit "S0324" as sampleid, kmer, cnt];
# S0325 = scan(kmercnt_11_rc_S0325_ol); R = R + [from S0325 emit "S0325" as sampleid, kmer, cnt];
# S0326 = scan(kmercnt_11_rc_S0326_ol); R = R + [from S0326 emit "S0326" as sampleid, kmer, cnt];
# S0328 = scan(kmercnt_11_rc_S0328_ol); R = R + [from S0328 emit "S0328" as sampleid, kmer, cnt];
# S0329 = scan(kmercnt_11_rc_S0329_ol); R = R + [from S0329 emit "S0329" as sampleid, kmer, cnt];
# S0331 = scan(kmercnt_11_rc_S0331_ol); R = R + [from S0331 emit "S0331" as sampleid, kmer, cnt];
# S0332 = scan(kmercnt_11_rc_S0332_ol); R = R + [from S0332 emit "S0332" as sampleid, kmer, cnt];
# S0333 = scan(kmercnt_11_rc_S0333_ol); R = R + [from S0333 emit "S0333" as sampleid, kmer, cnt];
# S0334 = scan(kmercnt_11_rc_S0334_ol); R = R + [from S0334 emit "S0334" as sampleid, kmer, cnt];
# S0335 = scan(kmercnt_11_rc_S0335_ol); R = R + [from S0335 emit "S0335" as sampleid, kmer, cnt];
# S0336 = scan(kmercnt_11_rc_S0336_ol); R = R + [from S0336 emit "S0336" as sampleid, kmer, cnt];
# S0337 = scan(kmercnt_11_rc_S0337_ol); R = R + [from S0337 emit "S0337" as sampleid, kmer, cnt];
# S0340 = scan(kmercnt_11_rc_S0340_ol); R = R + [from S0340 emit "S0340" as sampleid, kmer, cnt];
# S0341 = scan(kmercnt_11_rc_S0341_ol); R = R + [from S0341 emit "S0341" as sampleid, kmer, cnt];
# S0342 = scan(kmercnt_11_rc_S0342_ol); R = R + [from S0342 emit "S0342" as sampleid, kmer, cnt];
# S0343 = scan(kmercnt_11_rc_S0343_ol); R = R + [from S0343 emit "S0343" as sampleid, kmer, cnt];
# S0344 = scan(kmercnt_11_rc_S0344_ol); R = R + [from S0344 emit "S0344" as sampleid, kmer, cnt];
# S0345 = scan(kmercnt_11_rc_S0345_ol); R = R + [from S0345 emit "S0345" as sampleid, kmer, cnt];
# S0347 = scan(kmercnt_11_rc_S0347_ol); R = R + [from S0347 emit "S0347" as sampleid, kmer, cnt];
# S0348 = scan(kmercnt_11_rc_S0348_ol); R = R + [from S0348 emit "S0348" as sampleid, kmer, cnt];
# S0349 = scan(kmercnt_11_rc_S0349_ol); R = R + [from S0349 emit "S0349" as sampleid, kmer, cnt];
# S0350 = scan(kmercnt_11_rc_S0350_ol); R = R + [from S0350 emit "S0350" as sampleid, kmer, cnt];
# S0351 = scan(kmercnt_11_rc_S0351_ol); R = R + [from S0351 emit "S0351" as sampleid, kmer, cnt];
# S0352 = scan(kmercnt_11_rc_S0352_ol); R = R + [from S0352 emit "S0352" as sampleid, kmer, cnt];
# S0353 = scan(kmercnt_11_rc_S0353_ol); R = R + [from S0353 emit "S0353" as sampleid, kmer, cnt];
# S0354 = scan(kmercnt_11_rc_S0354_ol); R = R + [from S0354 emit "S0354" as sampleid, kmer, cnt];
# S0355 = scan(kmercnt_11_rc_S0355_ol); R = R + [from S0355 emit "S0355" as sampleid, kmer, cnt];
# S0356 = scan(kmercnt_11_rc_S0356_ol); R = R + [from S0356 emit "S0356" as sampleid, kmer, cnt];
# S0357 = scan(kmercnt_11_rc_S0357_ol); R = R + [from S0357 emit "S0357" as sampleid, kmer, cnt];
# S0358 = scan(kmercnt_11_rc_S0358_ol); R = R + [from S0358 emit "S0358" as sampleid, kmer, cnt];
# S0359 = scan(kmercnt_11_rc_S0359_ol); R = R + [from S0359 emit "S0359" as sampleid, kmer, cnt];
# S0360 = scan(kmercnt_11_rc_S0360_ol); R = R + [from S0360 emit "S0360" as sampleid, kmer, cnt];
# S0361 = scan(kmercnt_11_rc_S0361_ol); R = R + [from S0361 emit "S0361" as sampleid, kmer, cnt];
# S0362 = scan(kmercnt_11_rc_S0362_ol); R = R + [from S0362 emit "S0362" as sampleid, kmer, cnt];
# S0363 = scan(kmercnt_11_rc_S0363_ol); R = R + [from S0363 emit "S0363" as sampleid, kmer, cnt];
# S0365 = scan(kmercnt_11_rc_S0365_ol); R = R + [from S0365 emit "S0365" as sampleid, kmer, cnt];
# S0366 = scan(kmercnt_11_rc_S0366_ol); R = R + [from S0366 emit "S0366" as sampleid, kmer, cnt];
# S0367 = scan(kmercnt_11_rc_S0367_ol); R = R + [from S0367 emit "S0367" as sampleid, kmer, cnt];
# S0368 = scan(kmercnt_11_rc_S0368_ol); R = R + [from S0368 emit "S0368" as sampleid, kmer, cnt];
# S0369 = scan(kmercnt_11_rc_S0369_ol); R = R + [from S0369 emit "S0369" as sampleid, kmer, cnt];
# S0370 = scan(kmercnt_11_rc_S0370_ol); R = R + [from S0370 emit "S0370" as sampleid, kmer, cnt];
# S0371 = scan(kmercnt_11_rc_S0371_ol); R = R + [from S0371 emit "S0371" as sampleid, kmer, cnt];
# S0372 = scan(kmercnt_11_rc_S0372_ol); R = R + [from S0372 emit "S0372" as sampleid, kmer, cnt];
# S0373 = scan(kmercnt_11_rc_S0373_ol); R = R + [from S0373 emit "S0373" as sampleid, kmer, cnt];
# S0374 = scan(kmercnt_11_rc_S0374_ol); R = R + [from S0374 emit "S0374" as sampleid, kmer, cnt];
# S0375 = scan(kmercnt_11_rc_S0375_ol); R = R + [from S0375 emit "S0375" as sampleid, kmer, cnt];
# S0376 = scan(kmercnt_11_rc_S0376_ol); R = R + [from S0376 emit "S0376" as sampleid, kmer, cnt];
# S0377 = scan(kmercnt_11_rc_S0377_ol); R = R + [from S0377 emit "S0377" as sampleid, kmer, cnt];
# S0378 = scan(kmercnt_11_rc_S0378_ol); R = R + [from S0378 emit "S0378" as sampleid, kmer, cnt];
# S0379 = scan(kmercnt_11_rc_S0379_ol); R = R + [from S0379 emit "S0379" as sampleid, kmer, cnt];
# S0380 = scan(kmercnt_11_rc_S0380_ol); R = R + [from S0380 emit "S0380" as sampleid, kmer, cnt];
# S0381 = scan(kmercnt_11_rc_S0381_ol); R = R + [from S0381 emit "S0381" as sampleid, kmer, cnt];
# S0382 = scan(kmercnt_11_rc_S0382_ol); R = R + [from S0382 emit "S0382" as sampleid, kmer, cnt];
# S0383 = scan(kmercnt_11_rc_S0383_ol); R = R + [from S0383 emit "S0383" as sampleid, kmer, cnt];
# S0384 = scan(kmercnt_11_rc_S0384_ol); R = R + [from S0384 emit "S0384" as sampleid, kmer, cnt];
# S0385 = scan(kmercnt_11_rc_S0385_ol); R = R + [from S0385 emit "S0385" as sampleid, kmer, cnt];
# S0386 = scan(kmercnt_11_rc_S0386_ol); R = R + [from S0386 emit "S0386" as sampleid, kmer, cnt];
# S0387 = scan(kmercnt_11_rc_S0387_ol); R = R + [from S0387 emit "S0387" as sampleid, kmer, cnt];
# S0388 = scan(kmercnt_11_rc_S0388_ol); R = R + [from S0388 emit "S0388" as sampleid, kmer, cnt];
# S0389 = scan(kmercnt_11_rc_S0389_ol); R = R + [from S0389 emit "S0389" as sampleid, kmer, cnt];
# S0390 = scan(kmercnt_11_rc_S0390_ol); R = R + [from S0390 emit "S0390" as sampleid, kmer, cnt];
# S0391 = scan(kmercnt_11_rc_S0391_ol); R = R + [from S0391 emit "S0391" as sampleid, kmer, cnt];
# S0392 = scan(kmercnt_11_rc_S0392_ol); R = R + [from S0392 emit "S0392" as sampleid, kmer, cnt];
# S0393 = scan(kmercnt_11_rc_S0393_ol); R = R + [from S0393 emit "S0393" as sampleid, kmer, cnt];
# S0394 = scan(kmercnt_11_rc_S0394_ol); R = R + [from S0394 emit "S0394" as sampleid, kmer, cnt];
# S0395 = scan(kmercnt_11_rc_S0395_ol); R = R + [from S0395 emit "S0395" as sampleid, kmer, cnt];
# S0396 = scan(kmercnt_11_rc_S0396_ol); R = R + [from S0396 emit "S0396" as sampleid, kmer, cnt];
# S0397 = scan(kmercnt_11_rc_S0397_ol); R = R + [from S0397 emit "S0397" as sampleid, kmer, cnt];
# S0398 = scan(kmercnt_11_rc_S0398_ol); R = R + [from S0398 emit "S0398" as sampleid, kmer, cnt];
# S0401 = scan(kmercnt_11_rc_S0401_ol); R = R + [from S0401 emit "S0401" as sampleid, kmer, cnt];
# S0402 = scan(kmercnt_11_rc_S0402_ol); R = R + [from S0402 emit "S0402" as sampleid, kmer, cnt];
# S0403 = scan(kmercnt_11_rc_S0403_ol); R = R + [from S0403 emit "S0403" as sampleid, kmer, cnt];
# S0404 = scan(kmercnt_11_rc_S0404_ol); R = R + [from S0404 emit "S0404" as sampleid, kmer, cnt];
# S0405 = scan(kmercnt_11_rc_S0405_ol); R = R + [from S0405 emit "S0405" as sampleid, kmer, cnt];
# S0406 = scan(kmercnt_11_rc_S0406_ol); R = R + [from S0406 emit "S0406" as sampleid, kmer, cnt];
# S0407 = scan(kmercnt_11_rc_S0407_ol); R = R + [from S0407 emit "S0407" as sampleid, kmer, cnt];
# S0409 = scan(kmercnt_11_rc_S0409_ol); R = R + [from S0409 emit "S0409" as sampleid, kmer, cnt];
# S0410 = scan(kmercnt_11_rc_S0410_ol); R = R + [from S0410 emit "S0410" as sampleid, kmer, cnt];
# S0411 = scan(kmercnt_11_rc_S0411_ol); R = R + [from S0411 emit "S0411" as sampleid, kmer, cnt];
# S0415 = scan(kmercnt_11_rc_S0415_ol); R = R + [from S0415 emit "S0415" as sampleid, kmer, cnt];
# S0416 = scan(kmercnt_11_rc_S0416_ol); R = R + [from S0416 emit "S0416" as sampleid, kmer, cnt];
# S0419 = scan(kmercnt_11_rc_S0419_ol); R = R + [from S0419 emit "S0419" as sampleid, kmer, cnt];
# S0422 = scan(kmercnt_11_rc_S0422_ol); R = R + [from S0422 emit "S0422" as sampleid, kmer, cnt];
# S0423 = scan(kmercnt_11_rc_S0423_ol); R = R + [from S0423 emit "S0423" as sampleid, kmer, cnt];
# S0424 = scan(kmercnt_11_rc_S0424_ol); R = R + [from S0424 emit "S0424" as sampleid, kmer, cnt];
# S0425 = scan(kmercnt_11_rc_S0425_ol); R = R + [from S0425 emit "S0425" as sampleid, kmer, cnt];
# S0428 = scan(kmercnt_11_rc_S0428_ol); R = R + [from S0428 emit "S0428" as sampleid, kmer, cnt];
# S0429 = scan(kmercnt_11_rc_S0429_ol); R = R + [from S0429 emit "S0429" as sampleid, kmer, cnt];
# S0430 = scan(kmercnt_11_rc_S0430_ol); R = R + [from S0430 emit "S0430" as sampleid, kmer, cnt];
# S0431 = scan(kmercnt_11_rc_S0431_ol); R = R + [from S0431 emit "S0431" as sampleid, kmer, cnt];
# S0432 = scan(kmercnt_11_rc_S0432_ol); R = R + [from S0432 emit "S0432" as sampleid, kmer, cnt];
# S0435 = scan(kmercnt_11_rc_S0435_ol); R = R + [from S0435 emit "S0435" as sampleid, kmer, cnt];
# S0436 = scan(kmercnt_11_rc_S0436_ol); R = R + [from S0436 emit "S0436" as sampleid, kmer, cnt];
# S0437 = scan(kmercnt_11_rc_S0437_ol); R = R + [from S0437 emit "S0437" as sampleid, kmer, cnt];
# S0438 = scan(kmercnt_11_rc_S0438_ol); R = R + [from S0438 emit "S0438" as sampleid, kmer, cnt];
# S0443 = scan(kmercnt_11_rc_S0443_ol); R = R + [from S0443 emit "S0443" as sampleid, kmer, cnt];
# S0445 = scan(kmercnt_11_rc_S0445_ol); R = R + [from S0445 emit "S0445" as sampleid, kmer, cnt];
# store(R, kmercnt_11_rc_ol);

# %% [markdown]
# ## Sum together overlapped and non-overlapped kmers

# %%
# %%query
# ol = scan(kmercnt_11_forward_ol_Pkmer);
# nol = scan(kmercnt_11_forward_nol_Pkmer);
#
# olnol = select sampleid, kmer, o.cnt + o2.cnt as cnt
#             from ol o, nol o2
#             where o.kmer = o2.kmer
#             and o.sampleid = o2.sampleid;
#
# store(olnol, kmercnt_11_forward_Pkmer, [kmer]);

# %% [markdown]
# ## Compute degree table

# %%
# %%query
# T = scan(kmercnt_11_forward_Pkmer);
# sum_cnt = select sampleid, sum(cnt) as sum_cnt from T;
# store(sum_cnt, kmercnt_11_sum_Psample, [sampleid]);

# %% [markdown]
# ## Normalize kmer counts

# %% [markdown]
# Because some samples have more sequences than others, we normalize each kmer count by the total number of kmers in that sequence. The result is the frequency each kmer appears at.

# %%
# %%query
# Tcnt = scan(kmercnt_11_forward_Pkmer);
# Tsum = scan(kmercnt_11_sum_Psample);
# Tnorm = select sampleid, kmer, cnt / sum_cnt as norm_cnt
#     from Tcnt c, Tsum s
#     where c.sampleid = s.sampleid;
# store(Tnorm, kmercntnorm_11_forward_Pkmer, [kmer]);

# %% [markdown]
# # Compute diversity measures on kmer frequencies

# %% [markdown]
# The [**Simpson diversity**](https://en.wikipedia.org/wiki/Diversity_index#Simpson_index) is the probability that two kmers selected at random from the sample represent are the same.
#
# The **Entropy skew** is how far away the kmer distribution is from the maximum possible entropy, which is 22 bits for 11-mers.
#
# We also compute the mean, count, and standard deviation of the normalized kmer counts for each sample.

# %%
# %%query
# -- K=11: 4^11 = 4194304
# T1 = scan(kmercntnorm_11_forward_Pkmer);
# TMean = select sampleid, sum(norm_cnt) / 4194304 as mean,
# 		count(*) as nnz, sum(norm_cnt * norm_cnt) as simp,
# 		22 + sum(norm_cnt*log(norm_cnt)/log(2)) as entropy
# 	 	from T1;
# T3 = select t.sampleid, tm.mean, tm.nnz
#            (t.norm_cnt - tm.mean)*(t.norm_cnt - tm.mean) as stdevi,
#            tm.simp, tm.entropy
#       where t.sampleid = tm.sampleid
#      from T1 t, TMean tm;
# store(T3, kmercntnorm_11_forward_stats, [sampleid]);

# %% [markdown]
# # Compute Bray-Curtis Distances between samples

# %% [markdown]
# The [Bray-Curtis dissimilarity](https://en.wikipedia.org/wiki/Bray%E2%80%93Curtis_dissimilarity) is a common metric used in ecology to compare the composition of species at different sites.
#
# We run Bray-Curtis on the normalized kmer frequencies via the formula `1 - sum(min(a,b))`
# where `a` and `b` are the frequencies from two samples for a particular kmer. The sum is over all 4^11 kmers.
# We compute this for every pair of samples. In the visualization, we only display the ones we have environmental data for.

# %%
# %%query
# k = scan(kmercntnorm_11_forward_Pkmer);
# kmers = select * from k;
#
# X = select a.sampleid as asample, b.sampleid as bsample,
#     case when a.norm_cnt < b.norm_cnt then a.norm_cnt else b.norm_cnt end as minv
#     from kmers a, kmers b
#     where a.kmer = b.kmer
#     and a.sampleid < b.sampleid;
#
# Y = select asample, bsample, 1 - sum(minv) as BCdis
#     from X;
# store(Y, BC_full);

# %% [markdown]
# # Environmental Data

# %% [markdown]
# ## Pre-processing and ingest

# %% [markdown]
# The following file provides the location and pressure value at which each sample was collected.

# %%
# %%query
# C = load("file:///home/gridsan/dhutchison/gits/istc_oceanography/metadata/geotraces_conversion_bystation_v2.tsv",
# csv(schema(Library:string, Cruise:string, Station:int, BODC:int, CTDPRS:float, Date:string, Longitude:float, Latitude:float),skip=1,delimiter="\t"));
# store(C, GeotracesConversionBystation);
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>BODC</th>
#       <th>CTDPRS</th>
#       <th>Cruise</th>
#       <th>Date</th>
#       <th>Latitude</th>
#       <th>Library</th>
#       <th>Longitude</th>
#       <th>Station</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1608554</td>
#       <td>10.0</td>
#       <td>GA02</td>
#       <td>2010-05-10T10:40:29.000</td>
#       <td>49.72200</td>
#       <td>S0001</td>
#       <td>317.55310</td>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1608554</td>
#       <td>40.0</td>
#       <td>GA02</td>
#       <td>2010-05-10T10:40:29.000</td>
#       <td>49.72200</td>
#       <td>S0002</td>
#       <td>317.55310</td>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1608554</td>
#       <td>80.0</td>
#       <td>GA02</td>
#       <td>2010-05-10T10:40:29.000</td>
#       <td>49.72200</td>
#       <td>S0003</td>
#       <td>317.55310</td>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1608554</td>
#       <td>100.0</td>
#       <td>GA02</td>
#       <td>2010-05-10T10:40:29.000</td>
#       <td>49.72200</td>
#       <td>S0004</td>
#       <td>317.55310</td>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>1608554</td>
#       <td>160.0</td>
#       <td>GA02</td>
#       <td>2010-05-10T10:40:29.000</td>
#       <td>49.72200</td>
#       <td>S0005</td>
#       <td>317.55310</td>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>1608554</td>
#       <td>180.0</td>
#       <td>GA02</td>
#       <td>2010-05-10T10:40:29.000</td>
#       <td>49.72200</td>
#       <td>S0006</td>
#       <td>317.55310</td>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>1608603</td>
#       <td>10.0</td>
#       <td>GA02</td>
#       <td>2010-05-12T18:57:00.000</td>
#       <td>46.31190</td>
#       <td>S0008</td>
#       <td>320.34161</td>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>1608603</td>
#       <td>40.0</td>
#       <td>GA02</td>
#       <td>2010-05-12T18:57:00.000</td>
#       <td>46.31190</td>
#       <td>S0009</td>
#       <td>320.34161</td>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>1608603</td>
#       <td>80.0</td>
#       <td>GA02</td>
#       <td>2010-05-12T18:57:00.000</td>
#       <td>46.31190</td>
#       <td>S0010</td>
#       <td>320.34161</td>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>1608603</td>
#       <td>100.0</td>
#       <td>GA02</td>
#       <td>2010-05-12T18:57:00.000</td>
#       <td>46.31190</td>
#       <td>S0011</td>
#       <td>320.34161</td>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>1608603</td>
#       <td>160.0</td>
#       <td>GA02</td>
#       <td>2010-05-12T18:57:00.000</td>
#       <td>46.31190</td>
#       <td>S0012</td>
#       <td>320.34161</td>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>1608603</td>
#       <td>180.0</td>
#       <td>GA02</td>
#       <td>2010-05-12T18:57:00.000</td>
#       <td>46.31190</td>
#       <td>S0013</td>
#       <td>320.34161</td>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>1608687</td>
#       <td>10.0</td>
#       <td>GA02</td>
#       <td>2010-05-20T11:48:29.000</td>
#       <td>36.20510</td>
#       <td>S0015</td>
#       <td>306.70898</td>
#       <td>16</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>1608687</td>
#       <td>40.0</td>
#       <td>GA02</td>
#       <td>2010-05-20T11:48:29.000</td>
#       <td>36.20510</td>
#       <td>S0016</td>
#       <td>306.70898</td>
#       <td>16</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>1608687</td>
#       <td>80.0</td>
#       <td>GA02</td>
#       <td>2010-05-20T11:48:29.000</td>
#       <td>36.20510</td>
#       <td>S0017</td>
#       <td>306.70898</td>
#       <td>16</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>1608687</td>
#       <td>100.0</td>
#       <td>GA02</td>
#       <td>2010-05-20T11:48:29.000</td>
#       <td>36.20510</td>
#       <td>S0018</td>
#       <td>306.70898</td>
#       <td>16</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>1608687</td>
#       <td>160.0</td>
#       <td>GA02</td>
#       <td>2010-05-20T11:48:29.000</td>
#       <td>36.20510</td>
#       <td>S0019</td>
#       <td>306.70898</td>
#       <td>16</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>1608687</td>
#       <td>180.0</td>
#       <td>GA02</td>
#       <td>2010-05-20T11:48:29.000</td>
#       <td>36.20510</td>
#       <td>S0020</td>
#       <td>306.70898</td>
#       <td>16</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>1608673</td>
#       <td>10.0</td>
#       <td>GA02</td>
#       <td>2010-05-19T00:32:00.000</td>
#       <td>37.53450</td>
#       <td>S0021</td>
#       <td>309.21811</td>
#       <td>15</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>1608673</td>
#       <td>40.0</td>
#       <td>GA02</td>
#       <td>2010-05-19T00:32:00.000</td>
#       <td>37.53450</td>
#       <td>S0022</td>
#       <td>309.21811</td>
#       <td>15</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>1608673</td>
#       <td>80.0</td>
#       <td>GA02</td>
#       <td>2010-05-19T00:32:00.000</td>
#       <td>37.53450</td>
#       <td>S0023</td>
#       <td>309.21811</td>
#       <td>15</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>1608673</td>
#       <td>100.0</td>
#       <td>GA02</td>
#       <td>2010-05-19T00:32:00.000</td>
#       <td>37.53450</td>
#       <td>S0024</td>
#       <td>309.21811</td>
#       <td>15</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>1608673</td>
#       <td>160.0</td>
#       <td>GA02</td>
#       <td>2010-05-19T00:32:00.000</td>
#       <td>37.53450</td>
#       <td>S0025</td>
#       <td>309.21811</td>
#       <td>15</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>1608673</td>
#       <td>180.0</td>
#       <td>GA02</td>
#       <td>2010-05-19T00:32:00.000</td>
#       <td>37.53450</td>
#       <td>S0026</td>
#       <td>309.21811</td>
#       <td>15</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>1608701</td>
#       <td>10.0</td>
#       <td>GA02</td>
#       <td>2010-05-21T11:48:00.000</td>
#       <td>34.33070</td>
#       <td>S0027</td>
#       <td>304.57550</td>
#       <td>17</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>1608701</td>
#       <td>40.0</td>
#       <td>GA02</td>
#       <td>2010-05-21T11:48:00.000</td>
#       <td>34.33070</td>
#       <td>S0028</td>
#       <td>304.57550</td>
#       <td>17</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>1608701</td>
#       <td>80.0</td>
#       <td>GA02</td>
#       <td>2010-05-21T11:48:00.000</td>
#       <td>34.33070</td>
#       <td>S0029</td>
#       <td>304.57550</td>
#       <td>17</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>1608701</td>
#       <td>100.0</td>
#       <td>GA02</td>
#       <td>2010-05-21T11:48:00.000</td>
#       <td>34.33070</td>
#       <td>S0030</td>
#       <td>304.57550</td>
#       <td>17</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>1608701</td>
#       <td>160.0</td>
#       <td>GA02</td>
#       <td>2010-05-21T11:48:00.000</td>
#       <td>34.33070</td>
#       <td>S0031</td>
#       <td>304.57550</td>
#       <td>17</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>1608701</td>
#       <td>180.0</td>
#       <td>GA02</td>
#       <td>2010-05-21T11:48:00.000</td>
#       <td>34.33070</td>
#       <td>S0032</td>
#       <td>304.57550</td>
#       <td>17</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>1609079</td>
#       <td>10.0</td>
#       <td>GA02</td>
#       <td>2010-06-26T10:46:30.000</td>
#       <td>13.16200</td>
#       <td>S0033</td>
#       <td>306.57889</td>
#       <td>33</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>1609079</td>
#       <td>75.0</td>
#       <td>GA02</td>
#       <td>2010-06-26T10:46:30.000</td>
#       <td>13.16200</td>
#       <td>S0034</td>
#       <td>306.57889</td>
#       <td>33</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>1609079</td>
#       <td>100.0</td>
#       <td>GA02</td>
#       <td>2010-06-26T10:46:30.000</td>
#       <td>13.16200</td>
#       <td>S0035</td>
#       <td>306.57889</td>
#       <td>33</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>1609079</td>
#       <td>150.0</td>
#       <td>GA02</td>
#       <td>2010-06-26T10:46:30.000</td>
#       <td>13.16200</td>
#       <td>S0036</td>
#       <td>306.57889

# %% [markdown]
# The environmental data is quite small, compared to the genomic data. Many of the columns are sparse measurements; not every variable was measured at every depth of every site.
#
# The following code replaces missing values with 0s. It treats actual 0s as small values 0.000001s.
# Our choice of 0 facilitates the interpolation we run below when we link the environmental data to the genomic data, which was taken at a particular depth not necessarily equal to the depth environmental data was recorded.

# %%
import pandas as pd
data = pd.read_csv("file:///home/gridsan/dhutchison/gits/istc_oceanography/metadata/GA02_IDP2014_v2_Discrete_Sample_Data_cut.csv")

# %%
data = data.replace(0,0.000001) #Replace real 0s with an epsilon
#sum(data2["NITRAT [umol/kg]"] == 0.000001)
data = data.fillna(0) # Replace missing values with 0
data["Bottle Number"] = data["Bottle Number"].astype(int) #ensure all values are ints
zero_eps_file = "GA02_IDP2014_v2_Discrete_Sample_Data_cut_zero_eps.csv"
data.to_csv(zero_eps_file)

# %%
#file:///home/gridsan/dhutchison/gits/istc_oceanography/metadata/GA02_IDP2014_v2_Discrete_Sample_Data_cut_zero_eps.csv
import os
filepath = "file://%s" % join(os.getcwd(), zero_eps_file)
query = %myrial E = load("@filepath", \
                         csv(schema(rowid:int,Cruise:string,Station:int,Date:string,Longitude:float,Latitude:float,BotDepth:int,OperatorCruiseName:string, CTDPRS:float,CastId:string,SamplingDevice:string,BottleNumber:int,BODCBottleNumber:int,Depth:int,CTDTMP:float,CTDSAL:float, \
                                    OXYGEN:float,CTDOXY:float,PHSPHT:float,SILCAT:float,NITRAT:float,NITRIT:float,TALK:float,DIC:float,H2O_2_D_DELTA_BOTTLE:float,H2O_18_D_DELTA_BOTTLE:float,Al_D_CONC_BOTTLE:float,STANDARD_DEV:float,Ba_D_CONC_BOTTLE:float,Cd_D_CONC_BOTTLE:float,Fe_D_CONC_BOTTLE:float,Fe_D_CONC_BOTTLE_FIA:float,Fe_D_CONC_BOTTLE_FIA_STANDARD_DEV:float,Mn_D_CONC_BOTTLE:float,Mn_D_CONC_BOTTLE_STANDARD_DEV:float,Mo_D_CONC_BOTTLE:float,Ni_D_CONC_BOTTLE:float,Pb_D_CONC_BOTTLE:float,U_D_CONC_BOTTLE:float,Zn_D_CONC_BOTTLE:float,Y_D_CONC_BOTTLE:float,La_D_CONC_BOTTLE:float,Pa_231_D_CONC_BOTTLE:float,Pa_231_D_CONC_BOTTLE_STANDARD_DEV:float,Th_230_D_CONC_BOTTLE:float,Th_230_D_CONC_BOTTLE_STANDARD_DEV:float,Th_232_D_CONC_BOTTLE:float,Th_232_D_CONC_BOTTLE_STANDARD_DEV:float,Th_234_D_CONC_BOTTLE:float,Th_234_D_CONC_BOTTLE_STANDARD_DEV:float),skip=1,delimiter=",")); \
store(E, EnvironmentalData, [Station]);
print query.status
# Out:
# SUCCESS
# <function submit at 0x32088c0>

# %% [markdown]
# ## Interpolate environmental data to samples

# %% [markdown]
# Interpolation is awkward but doable in sql-like languages. There is a paper under review which proposes a new relational operator---interpolating join---to handle different kinds of interpolation on data of arbitrary dimension.
#
# Here is the logic for each sampleid:
#
# * (Majority case)  If there is an environmental data row for a pressure both above and below the pressure at which the sample was taken, then linearly interpolate between those two surrounding rows.
# * (10 samples taken at shallow depths fall into this case)  If there is an environmental data row for a pressure below the pressure at which the sample was taken but no row above, then assume the point above (nearest neighbor strategy).
# * No samples fell into the opposite case: having a point above but no point below.
# * We have no envionmental data for half the samples.  This is because we are missing conversion data for cruise GA03; i.e. we do not know where and at what depth the samples from cruise GA03 were taken.
#
# Here is the logic for each attribute (OXYGEN, SILCAT, PHSPHT, etc.), assuming there is a row above and below:
#
# * If the closest point above and below both have measurements, then interpolate between them.
# * If one of the closest points above or below is missing, then use the value of the one that is not missing.
# * Otherwise leave the data point as missing (a zero).

# %%
# %%query
# -- This query does linear interpolation on pressure (CTDPRS)
# -- between the conversion table C and the environmental metadata table E
# -- Extrapolation is limited to the nearest point
# C = scan(GeotracesConversionBystation);
# E = scan(EnvironmentalData);
#
# -- get the greatest pressure of E that is below C
# Below1 = select c.CTDPRS as pressure, c.Library, c.Station,
#     max(e.CTDPRS) as pressureBelow
# from C c, E e
# where c.Station = e.Station and e.CTDPRS <= c.CTDPRS
# and e.CTDPRS != 0;
#
# -- get the average of metadata from E that is at that pressure
# Below2 = select b.pressure, b.Library, b.Station, b.pressureBelow,
#     case when sum(case when e.Depth != 0 then 1 else 0 end) = 0 then 0.0 else sum(e.Depth) / sum(case when e.Depth != 0 then 1 else 0 end) end as depthBelow,
#  case when sum(case when e.CTDTMP != 0 then 1 else 0 end) = 0 then 0.0 else sum(e.CTDTMP) / sum(case when e.CTDTMP != 0 then 1 else 0 end) end as tempBelow,
#  case when sum(case when e.CTDTMP != 0 then 1 else 0 end) = 0 then 0.0 else sum(e.CTDSAL) / sum(case when e.CTDTMP != 0 then 1 else 0 end) end as salBelow,
# case when sum(case when e.OXYGEN != 0 then 1 else 0 end) = 0 then 0.0 else sum(e.OXYGEN) / sum(case when e.OXYGEN != 0 then 1 else 0 end) end as OXYGEN_Below,case when sum(case when e.CTDOXY != 0 then 1 else 0 end) = 0 then 0.0 else sum(e.CTDOXY) / sum(case when e.CTDOXY != 0 then 1 else 0 end) end as CTDOXY_Below,case when sum(case when e.PHSPHT != 0 then 1 else 0 end) = 0 then 0.0 else sum(e.PHSPHT) / sum(case when e.PHSPHT != 0 then 1 else 0 end) end as PHSPHT_Below,case when sum(case when e.SILCAT != 0 then 1 else 0 end) = 0 then 0.0 else sum(e.SILCAT) / sum(case when e.SILCAT != 0 then 1 else 0 end) end as SILCAT_Below,case when sum(case when e.NITRAT != 0 then 1 else 0 end) = 0 then 0.0 else sum(e.NITRAT) / sum(case when e.NITRAT != 0 then 1 else 0 end) end as NITRAT_Below,case when sum(case when e.NITRIT != 0 then 1 else 0 end) = 0 then 0.0 else sum(e.NITRIT) / sum(case when e.NITRIT != 0 then 1 else 0 end) end as NITRIT_Below,case when sum(case when e.TALK != 0 then 1 else 0 end) = 0 then 0.0 else sum(e.TALK) / sum(case when e.TALK != 0 then 1 else 0 end) end as TALK_Below,case when sum(case when e.DIC != 0 then 1 else 0 end) = 0 then 0.0 else sum(e.DIC) / sum(case when e.DIC != 0 then 1 else 0 end) end as DIC_Below,case when sum(case when e.H2O_2_D_DELTA_BOTTLE != 0 then 1 else 0 end) = 0 then 0.0 else sum(e.H2O_2_D_DELTA_BOTTLE) / sum(case when e.H2O_2_D_DELTA_BOTTLE != 0 then 1 else 0 end) end as H2O_2_D_DELTA_BOTTLE_Below,case when sum(case when e.H2O_18_D_DELTA_BOTTLE != 0 then 1 else 0 end) = 0 then 0.0 else sum(e.H2O_18_D_DELTA_BOTTLE) / sum(case when e.H2O_18_D_DELTA_BOTTLE != 0 then 1 else 0 end) end as H2O_18_D_DELTA_BOTTLE_Below,case when sum(case when e.Al_D_CONC_BOTTLE != 0 then 1 else 0 end) = 0 then 0.0 else sum(e.Al_D_CONC_BOTTLE) / sum(case when e.Al_D_CONC_BOTTLE != 0 then 1 else 0 end) end as Al_D_CONC_BOTTLE_Below,case when sum(case when e.STANDARD_DEV != 0 then 1 else 0 end) = 0 then 0.0 else sum(e.STANDARD_DEV) / sum(case when e.STANDARD_DEV != 0 then 1 else 0 end) end as STANDARD_DEV_Below,case when sum(case when e.Ba_D_CONC_BOTTLE != 0 then 1 else 0 end) = 0 then 0.0 else sum(e.Ba_D_CONC_BOTTLE) / sum(case when e.Ba_D_CONC_BOTTLE != 0 then 1 else 0 end) end as Ba_D_CONC_BOTTLE_Below,case when sum(case when e.Cd_D_CONC_BOTTLE != 0 then 1 else 0 end) = 0 then 0.0 else sum(e.Cd_D_CONC_BOTTLE) / sum(case when e.Cd_D_CONC_BOTTLE != 0 then 1 else 0 end) end as Cd_D_CONC_BOTTLE_Below,case when sum(case when e.Fe_D_CONC_BOTTLE != 0 then 1 else 0 end) = 0 then 0.0 else sum(e.Fe_D_CONC_BOTTLE) / sum(case when e.Fe_D_CONC_BOTTLE != 0 then 1 else 0 end) end as Fe_D_CONC_BOTTLE_Below,case when sum(case when e.Fe_D_CONC_BOTTLE_FIA != 0 then 1 else 0 end) = 0 then 0.0 else sum(e.Fe_D_CONC_BOTTLE_FIA) / sum(case when e.Fe_D_CONC_BOTTLE_FIA != 0 then 1 else 0 end) end as Fe_D_CONC_BOTTLE_FIA_Below,case when sum(case when e.Fe_D_CONC_BOTTLE_FIA_STANDARD_DEV != 0 then 1 else 0 end) = 0 then 0.0 else sum(e.Fe_D_CONC_BOTTLE_FIA_STANDARD_DEV) / sum(case when e.Fe_D_CONC_BOTTLE_FIA_STANDARD_DEV != 0 then 1 else 0 end) end as Fe_D_CONC_BOTTLE_FIA_STANDARD_DEV_Below,case when sum(case when e.Mn_D_CONC_BOTTLE != 0 then 1 else 0 end) = 0 then 0.0 else sum(e.Mn_D_CONC_BOTTLE) / sum(case when e.Mn_D_CONC_BOTTLE != 0 then 1 else 0 end) end as Mn_D_CONC_BOTTLE_Below,case when sum(case when e.Mn_D_CONC_BOTTLE_STANDARD_DEV != 0 then 1 else 0 end) = 0 then 0.0 else sum(e.Mn_D_CONC_BOTTLE_STANDARD_DEV) / sum(case when e.Mn_D_CONC_BOTTLE_STANDARD_DEV != 0 then 1 else 0 end) end as Mn_D_CONC_BOTTLE_STANDARD_DEV_Below,case when sum(case when e.Mo_D_CONC_BOTTLE != 0 then 1 else 0 end) = 0 then 0.0 else sum(e.Mo_D_CONC_BOTTLE) / sum(case when e.Mo_D_CONC_BOTTLE != 0 then 1 else 0 end) end as Mo_D_CONC_BOTTLE_Below,case when sum(case when e.Ni_D_CONC_BOTTLE != 0 then 1 else 0 end) = 0 then 0.0 else sum(e.Ni_D_CONC_BOTTLE) / sum(case when e.Ni_D_CONC_BOTTLE != 0 then 1 else 0 end) end as Ni_D_CONC_BOTTLE_Below,case when sum(case when e.Pb_D_CONC_BOTTLE != 0 then 1 else 0 end) = 0 then 0.0 else sum(e.Pb_D_CONC_BOTTLE) / sum(case when e.Pb_D_CONC_BOTTLE != 0 then 1 else 0 end) end as Pb_D_CONC_BOTTLE_Below,case when sum(case when e.U_D_CONC_BOTTLE != 0 then 1 else 0 end) = 0 then 0.0 else sum(e.U_D_CONC_BOTTLE) / sum(case when e.U_D_CONC_BOTTLE != 0 then 1 else 0 end) end as U_D_CONC_BOTTLE_Below,case when sum(case when e.Zn_D_CONC_BOTTLE != 0 then 1 else 0 end) = 0 then 0.0 else sum(e.Zn_D_CONC_BOTTLE) / sum(case when e.Zn_D_CONC_BOTTLE != 0 then 1 else 0 end) end as Zn_D_CONC_BOTTLE_Below,case when sum(case when e.Y_D_CONC_BOTTLE != 0 then 1 else 0 end) = 0 then 0.0 else sum(e.Y_D_CONC_BOTTLE) / sum(case when e.Y_D_CONC_BOTTLE != 0 then 1 else 0 end) end as Y_D_CONC_BOTTLE_Below,case when sum(case when e.La_D_CONC_BOTTLE != 0 then 1 else 0 end) = 0 then 0.0 else sum(e.La_D_CONC_BOTTLE) / sum(case when e.La_D_CONC_BOTTLE != 0 then 1 else 0 end) end as La_D_CONC_BOTTLE_Below,case when sum(case when e.Pa_231_D_CONC_BOTTLE != 0 then 1 else 0 end) = 0 then 0.0 else sum(e.Pa_231_D_CONC_BOTTLE) / sum(case when e.Pa_231_D_CONC_BOTTLE != 0 then 1 else 0 end) end as Pa_231_D_CONC_BOTTLE_Below,case when sum(case when e.Pa_231_D_CONC_BOTTLE_STANDARD_DEV != 0 then 1 else 0 end) = 0 then 0.0 else sum(e.Pa_231_D_CONC_BOTTLE_STANDARD_DEV) / sum(case when e.Pa_231_D_CONC_BOTTLE_STANDARD_DEV != 0 then 1 else 0 end) end as Pa_231_D_CONC_BOTTLE_STANDARD_DEV_Below,case when sum(case when e.Th_230_D_CONC_BOTTLE != 0 then 1 else 0 end) = 0 then 0.0 else sum(e.Th_230_D_CONC_BOTTLE) / sum(case when e.Th_230_D_CONC_BOTTLE != 0 then 1 else 0 end) end as Th_230_D_CONC_BOTTLE_Below,case when sum(case when e.Th_230_D_CONC_BOTTLE_STANDARD_DEV != 0 then 1 else 0 end) = 0 then 0.0 else sum(e.Th_230_D_CONC_BOTTLE_STANDARD_DEV) / sum(case when e.Th_230_D_CONC_BOTTLE_STANDARD_DEV != 0 then 1 else 0 end) end as Th_230_D_CONC_BOTTLE_STANDARD_DEV_Below,case when sum(case when e.Th_232_D_CONC_BOTTLE != 0 then 1 else 0 end) = 0 then 0.0 else sum(e.Th_232_D_CONC_BOTTLE) / sum(case when e.Th_232_D_CONC_BOTTLE != 0 then 1 else 0 end) end as Th_232_D_CONC_BOTTLE_Below,case when sum(case when e.Th_232_D_CONC_BOTTLE_STANDARD_DEV != 0 then 1 else 0 end) = 0 then 0.0 else sum(e.Th_232_D_CONC_BOTTLE_STANDARD_DEV) / sum(case when e.Th_232_D_CONC_BOTTLE_STANDARD_DEV != 0 then 1 else 0 end) end as Th_232_D_CONC_BOTTLE_STANDARD_DEV_Below,case when sum(case when e.Th_234_D_CONC_BOTTLE != 0 then 1 else 0 end) = 0 then 0.0 else sum(e.Th_234_D_CONC_BOTTLE) / sum(case when e.Th_234_D_CONC_BOTTLE != 0 then 1 else 0 end) end as Th_234_D_CONC_BOTTLE_Below,case when sum(case when e.Th_234_D_CONC_BOTTLE_STANDARD_DEV != 0 then 1 else 0 end) = 0 then 0.0 else sum(e.Th_234_D_CONC_BOTTLE_STANDARD_DEV) / sum(case when e.Th_234_D_CONC_BOTTLE_STANDARD_DEV != 0 then 1 else 0 end) end as Th_234_D_CONC_BOTTLE_STANDARD_DEV_Below
# from Below1 b, E e
# where b.Station = e.Station and b.pressureBelow = e.CTDPRS;
#
# -- get the least pressure of E that is above C
# Above1 = select c.CTDPRS as pressure, c.Library, c.Station,
#     min(e.CTDPRS) as pressureAbove
# from C c, E e
# where c.Station = e.Station and e.CTDPRS >= c.CTDPRS
# and c.CTDPRS != -1;
#
# -- get the average of metadata from E that is at that pressure
# Above2 = select a.pressure, a.Library, a.Station, a.pressureAbove,
#      case when sum(case when e.Depth != 0 then 1 else 0 end) = 0 then 0.0 else sum(e.Depth) / sum(case when e.Depth != 0 then 1 else 0 end) end as depthAbove,
#  case when sum(case when e.CTDTMP != 0 then 1 else 0 end) = 0 then 0.0 else sum(e.CTDTMP) / sum(case when e.CTDTMP != 0 then 1 else 0 end) end as tempAbove,
#  case when sum(case when e.CTDTMP != 0 then 1 else 0 end) = 0 then 0.0 else sum(e.CTDSAL) / sum(case when e.CTDTMP != 0 then 1 else 0 end) end as salAbove,
# case when sum(case when e.OXYGEN != 0 then 1 else 0 end) = 0 then 0.0 else sum(e.OXYGEN) / sum(case when e.OXYGEN != 0 then 1 else 0 end) end as OXYGEN_Above,case when sum(case when e.CTDOXY != 0 then 1 else 0 end) = 0 then 0.0 else sum(e.CTDOXY) / sum(case when e.CTDOXY != 0 then 1 else 0 end) end as CTDOXY_Above,case when sum(case when e.PHSPHT != 0 then 1 else 0 end) = 0 then 0.0 else sum(e.PHSPHT) / sum(case when e.PHSPHT != 0 then 1 else 0 end) end as PHSPHT_Above,case when sum(case when e.SILCAT != 0 then 1 else 0 end) = 0 then 0.0 else sum(e.SILCAT) / sum(case when e.SILCAT != 0 then 1 else 0 end) end as SILCAT_Above,case when sum(case when e.NITRAT != 0 then 1 else 0 end) = 0 then 0.0 else sum(e.NITRAT) / sum(case when e.NITRAT != 0 then 1 else 0 end) end as NITRAT_Above,case when sum(case when e.NITRIT != 0 then 1 else 0 end) = 0 then 0.0 else sum(e.NITRIT) / sum(case when e.NITRIT != 0 then 1 else 0 end) end as NITRIT_Above,case when sum(case when e.TALK != 0 then 1 else 0 end) = 0 then 0.0 else sum(e.TALK) / sum(case when e.TALK != 0 then 1 else 0 end) end as TALK_Above,case when sum(case when e.DIC != 0 then 1 else 0 end) = 0 then 0.0 else sum(e.DIC) / sum(case when e.DIC != 0 then 1 else 0 end) end as DIC_Above,case when sum(case when e.H2O_2_D_DELTA_BOTTLE != 0 then 1 else 0 end) = 0 then 0.0 else sum(e.H2O_2_D_DELTA_BOTTLE) / sum(case when e.H2O_2_D_DELTA_BOTTLE != 0 then 1 else 0 end) end as H2O_2_D_DELTA_BOTTLE_Above,case when sum(case when e.H2O_18_D_DELTA_BOTTLE != 0 then 1 else 0 end) = 0 then 0.0 else sum(e.H2O_18_D_DELTA_BOTTLE) / sum(case when e.H2O_18_D_DELTA_BOTTLE != 0 then 1 else 0 end) end as H2O_18_D_DELTA_BOTTLE_Above,case when sum(case when e.Al_D_CONC_BOTTLE != 0 then 1 else 0 end) = 0 then 0.0 else sum(e.Al_D_CONC_BOTTLE) / sum(case when e.Al_D_CONC_BOTTLE != 0 then 1 else 0 end) end as Al_D_CONC_BOTTLE_Above,case when sum(case when e.STANDARD_DEV != 0 then 1 else 0 end) = 0 then 0.0 else sum(e.STANDARD_DEV) / sum(case when e.STANDARD_DEV != 0 then 1 else 0 end) end as STANDARD_DEV_Above,case when sum(case when e.Ba_D_CONC_BOTTLE != 0 then 1 else 0 end) = 0 then 0.0 else sum(e.Ba_D_CONC_BOTTLE) / sum(case when e.Ba_D_CONC_BOTTLE != 0 then 1 else 0 end) end as Ba_D_CONC_BOTTLE_Above,case when sum(case when e.Cd_D_CONC_BOTTLE != 0 then 1 else 0 end) = 0 then 0.0 else sum(e.Cd_D_CONC_BOTTLE) / sum(case when e.Cd_D_CONC_BOTTLE != 0 then 1 else 0 end) end as Cd_D_CONC_BOTTLE_Above,case when sum(case when e.Fe_D_CONC_BOTTLE != 0 then 1 else 0 end) = 0 then 0.0 else sum(e.Fe_D_CONC_BOTTLE) / sum(case when e.Fe_D_CONC_BOTTLE != 0 then 1 else 0 end) end as Fe_D_CONC_BOTTLE_Above,case when sum(case when e.Fe_D_CONC_BOTTLE_FIA != 0 then 1 else 0 end) = 0 then 0.0 else sum(e.Fe_D_CONC_BOTTLE_FIA) / sum(case when e.Fe_D_CONC_BOTTLE_FIA != 0 then 1 else 0 end) end as Fe_D_CONC_BOTTLE_FIA_Above,case when sum(case when e.Fe_D_CONC_BOTTLE_FIA_STANDARD_DEV != 0 then 1 else 0 end) = 0 then 0.0 else sum(e.Fe_D_CONC_BOTTLE_FIA_STANDARD_DEV) / sum(case when e.Fe_D_CONC_BOTTLE_FIA_STANDARD_DEV != 0 then 1 else 0 end) end as Fe_D_CONC_BOTTLE_FIA_STANDARD_DEV_Above,case when sum(case when e.Mn_D_CONC_BOTTLE != 0 then 1 else 0 end) = 0 then 0.0 else sum(e.Mn_D_CONC_BOTTLE) / sum(case when e.Mn_D_CONC_BOTTLE != 0 then 1 else 0 end) end as Mn_D_CONC_BOTTLE_Above,case when sum(case when e.Mn_D_CONC_BOTTLE_STANDARD_DEV != 0 then 1 else 0 end) = 0 then 0.0 else sum(e.Mn_D_CONC_BOTTLE_STANDARD_DEV) / sum(case when e.Mn_D_CONC_BOTTLE_STANDARD_DEV != 0 then 1 else 0 end) end as Mn_D_CONC_BOTTLE_STANDARD_DEV_Above,case when sum(case when e.Mo_D_CONC_BOTTLE != 0 then 1 else 0 end) = 0 then 0.0 else sum(e.Mo_D_CONC_BOTTLE) / sum(case when e.Mo_D_CONC_BOTTLE != 0 then 1 else 0 end) end as Mo_D_CONC_BOTTLE_Above,case when sum(case when e.Ni_D_CONC_BOTTLE != 0 then 1 else 0 end) = 0 then 0.0 else sum(e.Ni_D_CONC_BOTTLE) / sum(case when e.Ni_D_CONC_BOTTLE != 0 then 1 else 0 end) end as Ni_D_CONC_BOTTLE_Above,case when sum(case when e.Pb_D_CONC_BOTTLE != 0 then 1 else 0 end) = 0 then 0.0 else sum(e.Pb_D_CONC_BOTTLE) / sum(case when e.Pb_D_CONC_BOTTLE != 0 then 1 else 0 end) end as Pb_D_CONC_BOTTLE_Above,case when sum(case when e.U_D_CONC_BOTTLE != 0 then 1 else 0 end) = 0 then 0.0 else sum(e.U_D_CONC_BOTTLE) / sum(case when e.U_D_CONC_BOTTLE != 0 then 1 else 0 end) end as U_D_CONC_BOTTLE_Above,case when sum(case when e.Zn_D_CONC_BOTTLE != 0 then 1 else 0 end) = 0 then 0.0 else sum(e.Zn_D_CONC_BOTTLE) / sum(case when e.Zn_D_CONC_BOTTLE != 0 then 1 else 0 end) end as Zn_D_CONC_BOTTLE_Above,case when sum(case when e.Y_D_CONC_BOTTLE != 0 then 1 else 0 end) = 0 then 0.0 else sum(e.Y_D_CONC_BOTTLE) / sum(case when e.Y_D_CONC_BOTTLE != 0 then 1 else 0 end) end as Y_D_CONC_BOTTLE_Above,case when sum(case when e.La_D_CONC_BOTTLE != 0 then 1 else 0 end) = 0 then 0.0 else sum(e.La_D_CONC_BOTTLE) / sum(case when e.La_D_CONC_BOTTLE != 0 then 1 else 0 end) end as La_D_CONC_BOTTLE_Above,case when sum(case when e.Pa_231_D_CONC_BOTTLE != 0 then 1 else 0 end) = 0 then 0.0 else sum(e.Pa_231_D_CONC_BOTTLE) / sum(case when e.Pa_231_D_CONC_BOTTLE != 0 then 1 else 0 end) end as Pa_231_D_CONC_BOTTLE_Above,case when sum(case when e.Pa_231_D_CONC_BOTTLE_STANDARD_DEV != 0 then 1 else 0 end) = 0 then 0.0 else sum(e.Pa_231_D_CONC_BOTTLE_STANDARD_DEV) / sum(case when e.Pa_231_D_CONC_BOTTLE_STANDARD_DEV != 0 then 1 else 0 end) end as Pa_231_D_CONC_BOTTLE_STANDARD_DEV_Above,case when sum(case when e.Th_230_D_CONC_BOTTLE != 0 then 1 else 0 end) = 0 then 0.0 else sum(e.Th_230_D_CONC_BOTTLE) / sum(case when e.Th_230_D_CONC_BOTTLE != 0 then 1 else 0 end) end as Th_230_D_CONC_BOTTLE_Above,case when sum(case when e.Th_230_D_CONC_BOTTLE_STANDARD_DEV != 0 then 1 else 0 end) = 0 then 0.0 else sum(e.Th_230_D_CONC_BOTTLE_STANDARD_DEV) / sum(case when e.Th_230_D_CONC_BOTTLE_STANDARD_DEV != 0 then 1 else 0 end) end as Th_230_D_CONC_BOTTLE_STANDARD_DEV_Above,case when sum(case when e.Th_232_D_CONC_BOTTLE != 0 then 1 else 0 end) = 0 then 0.0 else sum(e.Th_232_D_CONC_BOTTLE) / sum(case when e.Th_232_D_CONC_BOTTLE != 0 then 1 else 0 end) end as Th_232_D_CONC_BOTTLE_Above,case when sum(case when e.Th_232_D_CONC_BOTTLE_STANDARD_DEV != 0 then 1 else 0 end) = 0 then 0.0 else sum(e.Th_232_D_CONC_BOTTLE_STANDARD_DEV) / sum(case when e.Th_232_D_CONC_BOTTLE_STANDARD_DEV != 0 then 1 else 0 end) end as Th_232_D_CONC_BOTTLE_STANDARD_DEV_Above,case when sum(case when e.Th_234_D_CONC_BOTTLE != 0 then 1 else 0 end) = 0 then 0.0 else sum(e.Th_234_D_CONC_BOTTLE) / sum(case when e.Th_234_D_CONC_BOTTLE != 0 then 1 else 0 end) end as Th_234_D_CONC_BOTTLE_Above,case when sum(case when e.Th_234_D_CONC_BOTTLE_STANDARD_DEV != 0 then 1 else 0 end) = 0 then 0.0 else sum(e.Th_234_D_CONC_BOTTLE_STANDARD_DEV) / sum(case when e.Th_234_D_CONC_BOTTLE_STANDARD_DEV != 0 then 1 else 0 end) end as Th_234_D_CONC_BOTTLE_STANDARD_DEV_Above
# from Above1 a, E e
# where a.Station = e.Station and a.pressureAbove = e.CTDPRS;
#
# -- The next section is for extrapolation onto points
# -- with a pressure either above or below but not both
# Above2Lib = select Library from Above2;
# Below2Lib = select Library from Below2;
#
# AboveNotBelowLib = diff(Above2Lib, Below2Lib);
# AboveNotBelow = select a.Library, a.Station, a.pressure,
#     a.depthAbove as depth,
#     a.tempAbove as temp,
#     a.salAbove as sal,
# a.OXYGEN_Above as OXYGEN,a.CTDOXY_Above as CTDOXY,a.PHSPHT_Above as PHSPHT,a.SILCAT_Above as SILCAT,a.NITRAT_Above as NITRAT,a.NITRIT_Above as NITRIT,a.TALK_Above as TALK,a.DIC_Above as DIC,a.H2O_2_D_DELTA_BOTTLE_Above as H2O_2_D_DELTA_BOTTLE,a.H2O_18_D_DELTA_BOTTLE_Above as H2O_18_D_DELTA_BOTTLE,a.Al_D_CONC_BOTTLE_Above as Al_D_CONC_BOTTLE,a.STANDARD_DEV_Above as STANDARD_DEV,a.Ba_D_CONC_BOTTLE_Above as Ba_D_CONC_BOTTLE,a.Cd_D_CONC_BOTTLE_Above as Cd_D_CONC_BOTTLE,a.Fe_D_CONC_BOTTLE_Above as Fe_D_CONC_BOTTLE,a.Fe_D_CONC_BOTTLE_FIA_Above as Fe_D_CONC_BOTTLE_FIA,a.Fe_D_CONC_BOTTLE_FIA_STANDARD_DEV_Above as Fe_D_CONC_BOTTLE_FIA_STANDARD_DEV,a.Mn_D_CONC_BOTTLE_Above as Mn_D_CONC_BOTTLE,a.Mn_D_CONC_BOTTLE_STANDARD_DEV_Above as Mn_D_CONC_BOTTLE_STANDARD_DEV,a.Mo_D_CONC_BOTTLE_Above as Mo_D_CONC_BOTTLE,a.Ni_D_CONC_BOTTLE_Above as Ni_D_CONC_BOTTLE,a.Pb_D_CONC_BOTTLE_Above as Pb_D_CONC_BOTTLE,a.U_D_CONC_BOTTLE_Above as U_D_CONC_BOTTLE,a.Zn_D_CONC_BOTTLE_Above as Zn_D_CONC_BOTTLE,a.Y_D_CONC_BOTTLE_Above as Y_D_CONC_BOTTLE,a.La_D_CONC_BOTTLE_Above as La_D_CONC_BOTTLE,a.Pa_231_D_CONC_BOTTLE_Above as Pa_231_D_CONC_BOTTLE,a.Pa_231_D_CONC_BOTTLE_STANDARD_DEV_Above as Pa_231_D_CONC_BOTTLE_STANDARD_DEV,a.Th_230_D_CONC_BOTTLE_Above as Th_230_D_CONC_BOTTLE,a.Th_230_D_CONC_BOTTLE_STANDARD_DEV_Above as Th_230_D_CONC_BOTTLE_STANDARD_DEV,a.Th_232_D_CONC_BOTTLE_Above as Th_232_D_CONC_BOTTLE,a.Th_232_D_CONC_BOTTLE_STANDARD_DEV_Above as Th_232_D_CONC_BOTTLE_STANDARD_DEV,a.Th_234_D_CONC_BOTTLE_Above as Th_234_D_CONC_BOTTLE,a.Th_234_D_CONC_BOTTLE_STANDARD_DEV_Above as Th_234_D_CONC_BOTTLE_STANDARD_DEV
# from AboveNotBelowLib d, Above2 a
# where d.Library = a.Library;
# store(AboveNotBelow, AboveNotBelow);
#
# BelowNotAboveLib = diff(Below2Lib, Above2Lib);
# BelowNotAbove = select a.Library, a.Station, a.pressure,
#     a.depthBelow as depth,
#     a.tempBelow as temp,
#     a.salBelow as sal,
# a.OXYGEN_Below as OXYGEN,a.CTDOXY_Below as CTDOXY,a.PHSPHT_Below as PHSPHT,a.SILCAT_Below as SILCAT,a.NITRAT_Below as NITRAT,a.NITRIT_Below as NITRIT,a.TALK_Below as TALK,a.DIC_Below as DIC,a.H2O_2_D_DELTA_BOTTLE_Below as H2O_2_D_DELTA_BOTTLE,a.H2O_18_D_DELTA_BOTTLE_Below as H2O_18_D_DELTA_BOTTLE,a.Al_D_CONC_BOTTLE_Below as Al_D_CONC_BOTTLE,a.STANDARD_DEV_Below as STANDARD_DEV,a.Ba_D_CONC_BOTTLE_Below as Ba_D_CONC_BOTTLE,a.Cd_D_CONC_BOTTLE_Below as Cd_D_CONC_BOTTLE,a.Fe_D_CONC_BOTTLE_Below as Fe_D_CONC_BOTTLE,a.Fe_D_CONC_BOTTLE_FIA_Below as Fe_D_CONC_BOTTLE_FIA,a.Fe_D_CONC_BOTTLE_FIA_STANDARD_DEV_Below as Fe_D_CONC_BOTTLE_FIA_STANDARD_DEV,a.Mn_D_CONC_BOTTLE_Below as Mn_D_CONC_BOTTLE,a.Mn_D_CONC_BOTTLE_STANDARD_DEV_Below as Mn_D_CONC_BOTTLE_STANDARD_DEV,a.Mo_D_CONC_BOTTLE_Below as Mo_D_CONC_BOTTLE,a.Ni_D_CONC_BOTTLE_Below as Ni_D_CONC_BOTTLE,a.Pb_D_CONC_BOTTLE_Below as Pb_D_CONC_BOTTLE,a.U_D_CONC_BOTTLE_Below as U_D_CONC_BOTTLE,a.Zn_D_CONC_BOTTLE_Below as Zn_D_CONC_BOTTLE,a.Y_D_CONC_BOTTLE_Below as Y_D_CONC_BOTTLE,a.La_D_CONC_BOTTLE_Below as La_D_CONC_BOTTLE,a.Pa_231_D_CONC_BOTTLE_Below as Pa_231_D_CONC_BOTTLE,a.Pa_231_D_CONC_BOTTLE_STANDARD_DEV_Below as Pa_231_D_CONC_BOTTLE_STANDARD_DEV,a.Th_230_D_CONC_BOTTLE_Below as Th_230_D_CONC_BOTTLE,a.Th_230_D_CONC_BOTTLE_STANDARD_DEV_Below as Th_230_D_CONC_BOTTLE_STANDARD_DEV,a.Th_232_D_CONC_BOTTLE_Below as Th_232_D_CONC_BOTTLE,a.Th_232_D_CONC_BOTTLE_STANDARD_DEV_Below as Th_232_D_CONC_BOTTLE_STANDARD_DEV,a.Th_234_D_CONC_BOTTLE_Below as Th_234_D_CONC_BOTTLE,a.Th_234_D_CONC_BOTTLE_STANDARD_DEV_Below as Th_234_D_CONC_BOTTLE_STANDARD_DEV
# from BelowNotAboveLib d, Below2 a
# where d.Library = a.Library;
# store(BelowNotAbove, BelowNotAbove);
#
# -- Start of interpolation
# Both1 = select distinct b.Library, b.Station, b.pressure, a.pressureAbove, b.pressureBelow,
#     (a.pressureAbove - a.pressure) / (a.pressureAbove - b.pressureBelow) as mult,
#     a.tempAbove, b.tempBelow,
#     a.depthAbove, b.depthBelow,
#     a.salAbove, b.salBelow,
# a.OXYGEN_Above, b.OXYGEN_Below,a.CTDOXY_Above, b.CTDOXY_Below,a.PHSPHT_Above, b.PHSPHT_Below,a.SILCAT_Above, b.SILCAT_Below,a.NITRAT_Above, b.NITRAT_Below,a.NITRIT_Above, b.NITRIT_Below,a.TALK_Above, b.TALK_Below,a.DIC_Above, b.DIC_Below,a.H2O_2_D_DELTA_BOTTLE_Above, b.H2O_2_D_DELTA_BOTTLE_Below,a.H2O_18_D_DELTA_BOTTLE_Above, b.H2O_18_D_DELTA_BOTTLE_Below,a.Al_D_CONC_BOTTLE_Above, b.Al_D_CONC_BOTTLE_Below,a.STANDARD_DEV_Above, b.STANDARD_DEV_Below,a.Ba_D_CONC_BOTTLE_Above, b.Ba_D_CONC_BOTTLE_Below,a.Cd_D_CONC_BOTTLE_Above, b.Cd_D_CONC_BOTTLE_Below,a.Fe_D_CONC_BOTTLE_Above, b.Fe_D_CONC_BOTTLE_Below,a.Fe_D_CONC_BOTTLE_FIA_Above, b.Fe_D_CONC_BOTTLE_FIA_Below,a.Fe_D_CONC_BOTTLE_FIA_STANDARD_DEV_Above, b.Fe_D_CONC_BOTTLE_FIA_STANDARD_DEV_Below,a.Mn_D_CONC_BOTTLE_Above, b.Mn_D_CONC_BOTTLE_Below,a.Mn_D_CONC_BOTTLE_STANDARD_DEV_Above, b.Mn_D_CONC_BOTTLE_STANDARD_DEV_Below,a.Mo_D_CONC_BOTTLE_Above, b.Mo_D_CONC_BOTTLE_Below,a.Ni_D_CONC_BOTTLE_Above, b.Ni_D_CONC_BOTTLE_Below,a.Pb_D_CONC_BOTTLE_Above, b.Pb_D_CONC_BOTTLE_Below,a.U_D_CONC_BOTTLE_Above, b.U_D_CONC_BOTTLE_Below,a.Zn_D_CONC_BOTTLE_Above, b.Zn_D_CONC_BOTTLE_Below,a.Y_D_CONC_BOTTLE_Above, b.Y_D_CONC_BOTTLE_Below,a.La_D_CONC_BOTTLE_Above, b.La_D_CONC_BOTTLE_Below,a.Pa_231_D_CONC_BOTTLE_Above, b.Pa_231_D_CONC_BOTTLE_Below,a.Pa_231_D_CONC_BOTTLE_STANDARD_DEV_Above, b.Pa_231_D_CONC_BOTTLE_STANDARD_DEV_Below,a.Th_230_D_CONC_BOTTLE_Above, b.Th_230_D_CONC_BOTTLE_Below,a.Th_230_D_CONC_BOTTLE_STANDARD_DEV_Above, b.Th_230_D_CONC_BOTTLE_STANDARD_DEV_Below,a.Th_232_D_CONC_BOTTLE_Above, b.Th_232_D_CONC_BOTTLE_Below,a.Th_232_D_CONC_BOTTLE_STANDARD_DEV_Above, b.Th_232_D_CONC_BOTTLE_STANDARD_DEV_Below,a.Th_234_D_CONC_BOTTLE_Above, b.Th_234_D_CONC_BOTTLE_Below,a.Th_234_D_CONC_BOTTLE_STANDARD_DEV_Above, b.Th_234_D_CONC_BOTTLE_STANDARD_DEV_Below
# from Below2 b, Above2 a
# where b.Station = a.Station and b.pressure = a.pressure;
# Store(Both1, SampleToEnvironmental_temporary, [Library]);
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Al_D_CONC_BOTTLE</th>
#       <th>Ba_D_CONC_BOTTLE</th>
#       <th>CTDOXY</th>
#       <th>Cd_D_CONC_BOTTLE</th>
#       <th>DIC</th>
#       <th>Fe_D_CONC_BOTTLE</th>
#       <th>Fe_D_CONC_BOTTLE_FIA</th>
#       <th>Fe_D_CONC_BOTTLE_FIA_STANDARD_DEV</th>
#       <th>H2O_18_D_DELTA_BOTTLE</th>
#       <th>H2O_2_D_DELTA_BOTTLE</th>
#       <th>La_D_CONC_BOTTLE</th>
#       <th>Library</th>
#       <th>Mn_D_CONC_BOTTLE</th>
#       <th>Mn_D_CONC_BOTTLE_STANDARD_DEV</th>
#       <th>Mo_D_CONC_BOTTLE</th>
#       <th>NITRAT</th>
#       <th>NITRIT</th>
#       <th>Ni_D_CONC_BOTTLE</th>
#       <th>OXYGEN</th>
#       <th>PHSPHT</th>
#       <th>Pa_231_D_CONC_BOTTLE</th>
#       <th>Pa_231_D_CONC_BOTTLE_STANDARD_DEV</th>
#       <th>Pb_D_CONC_BOTTLE</th>
#       <th>SILCAT</th>
#       <th>STANDARD_DEV</th>
#       <th>Station</th>
#       <th>TALK</th>
#       <th>Th_230_D_CONC_BOTTLE</th>
#       <th>Th_230_D_CONC_BOTTLE_STANDARD_DEV</th>
#       <th>Th_232_D_CONC_BOTTLE</th>
#       <th>Th_232_D_CONC_BOTTLE_STANDARD_DEV</th>
#       <th>Th_234_D_CONC_BOTTLE</th>
#       <th>Th_234_D_CONC_BOTTLE_STANDARD_DEV</th>
#       <th>U_D_CONC_BOTTLE</th>
#       <th>Y_D_CONC_BOTTLE</th>
#       <th>Zn_D_CONC_BOTTLE</th>
#       <th>depth</th>
#       <th>pressure</th>
#       <th>sal</th>
#       <th>temp</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>42.819500</td>
#       <td>0.0000</td>
#       <td>194.8</td>
#       <td>0.00050</td>
#       <td>2016.6</td>
#       <td>1.44</td>
#       <td>1.532680</td>
#       <td>0.049760</td>
#       <td>0.00</td>
#       <td>0.00</td>
#       <td>18.250</td>
#       <td>S0152</td>
#       <td>3.531710</td>
#       <td>0.02634</td>
#       <td>0.000</td>
#       <td>0.000001</td>
#       <td>0.015000</td>
#       <td>2.000</td>
#       <td>0.0</td>
#       <td>0.010</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>22.010</td>
#       <td>1.100000</td>
#       <td>0.136580</td>
#       <td>27</td>
#       <td>2367.2</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0000</td>
#       <td>0.00000</td>
#       <td>0.0000</td>
#       <td>138.85001</td>
#       <td>0.020</td>
#       <td>12.0</td>
#       <td>10.0</td>
#       <td>36.141500</td>
#       <td>28.409000</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>3.292685</td>
#       <td>38.1073</td>
#       <td>255.2</td>
#       <td>0.01635</td>
#       <td>2068.5</td>
#       <td>0.14</td>
#       <td>0.138050</td>
#       <td>0.005370</td>
#       <td>0.18</td>
#       <td>4.98</td>
#       <td>20.865</td>
#       <td>S0243</td>
#       <td>0.936585</td>
#       <td>0.00878</td>
#       <td>144.160</td>
#       <td>0.200000</td>
#       <td>0.053333</td>
#       <td>2.815</td>
#       <td>210.3</td>
#       <td>0.090</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>20.170</td>
#       <td>0.753333</td>
#       <td>0.043900</td>
#       <td>10</td>
#       <td>2310.8</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>35.4927</td>
#       <td>0.80000</td>
#       <td>12.6078</td>
#       <td>122.78000</td>
#       <td>0.165</td>
#       <td>10.0</td>
#       <td>2.0</td>
#       <td>35.038667</td>
#       <td>15.072333</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>12.614600</td>
#       <td>42.7746</td>
#       <td>193.9</td>
#       <td>0.00130</td>
#       <td>2078.3</td>
#       <td>0.10</td>
#       <td>0.078050</td>
#       <td>0.000000</td>
#       <td>0.98</td>
#       <td>7.41</td>
#       <td>16.500</td>
#       <td>S0191</td>
#       <td>1.658540</td>
#       <td>0.03707</td>
#       <td>148.461</td>
#       <td>0.000001</td>
#       <td>0.020000</td>
#       <td>2.470</td>
#       <td>0.0</td>
#       <td>0.095</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>16.270</td>
#       <td>0.445000</td>
#       <td>0.107320</td>
#       <td>14</td>
#       <td>2429.7</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>36.6244</td>
#       <td>0.75122</td>
#       <td>12.9766</td>
#       <td>101.04000</td>
#       <td>0.170</td>
#       <td>10.0</td>
#       <td>10.0</td>
#       <td>37.017001</td>
#       <td>28.117500</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1.985365</td>
#       <td>46.9873</td>
#       <td>267.7</td>
#       <td>0.11765</td>
#       <td>2088.8</td>
#       <td>0.09</td>
#       <td>0.080975</td>
#       <td>0.008295</td>
#       <td>0.12</td>
#       <td>0.94</td>
#       <td>17.265</td>
#       <td>S0214</td>
#       <td>0.668295</td>
#       <td>0.00683</td>
#       <td>126.356</td>
#       <td>6.807500</td>
#       <td>0.100000</td>
#       <td>3.685</td>
#       <td>241.9</td>
#       <td>0.530</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>21.615</td>
#       <td>3.175000</td>
#       <td>0.019515</td>
#       <td>3</td>
#       <td>2305.2</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>21.4829</td>
#       <td>0.53658</td>
#       <td>12.4400</td>
#       <td>119.74000</td>
#       <td>0.515</td>
#       <td>10.0</td>
#       <td>10.0</td>
#       <td>34.813499</td>
#       <td>11.465000</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>3.292685</td>
#       <td>38.1073</td>
#       <td>255.2</td>
#       <td>0.01635</td>
#       <td>2068.5</td>
#       <td>0.14</td>
#       <td>0.138050</td>
#       <td>0.005370</td>
#       <td>0.18</td>
#       <td>4.98</td>
#       <td>20.865</td>
#       <td>S0001</td>
#       <td>0.936585</td>
#       <td>0.00878</td>
#       <td>144.160</td>
#       <td>0.200000</td>
#       <td>0.053333</td>
#       <td>2.815</td>
#       <td>210.3</td>
#       <td>0.090</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>20.170</td>
#       <td>0.753333</td>
#       <td>0.043900</td>
#       <td>10</td>
#       <td>2310.8</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>35.4927</td>
#       <td>0.80000</td>
#       <td>12.6078</td>
#       <td>122.78000</td>
#       <td>0.165</td>
#       <td>10.0</td>
#       <td>10.0</td>
#       <td>35.038667</td>
#       <td>15.072333</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>4.419510</td>
#       <td>48.7639</td>
#       <td>287.8</td>
#       <td>0.05280</td>
#       <td>2073.1</td>
#       <td>0.52</td>
#       <td>0.497560</td>
#       <td>0.019510</td>
#       <td>-0.26</td>
#       <td>-1.78</td>
#       <td>11.050</td>
#       <td>S0209</td>
#       <td>0.087800</td>
#       <td>0.00098</td>
#       <td>118.365</td>
#       <td>13.145000</td>
#       <td>0.165000</td>
#       <td>4.880</td>
#       <td>285.6</td>
#       <td>1.010</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>14.940</td>
#       <td>0.000001</td>
#       <td>0.117070</td>
#       <td>1</td>
#       <td>2277.8</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>25.0829</td>
#       <td>0.60488</td>
#       <td>11.6117</td>
#       <td>114.88000</td>
#       <td>0.210</td>
#       <td>10.0</td>
#       <td>10.0</td>
#       <td>33.977501</td>
#       <td>10.093000</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>41.424400</td>
#       <td>0.0000</td>
#       <td>203.5</td>
#       <td>0.00050</td>
#       <td>0.0</td>
#       <td>1.77</td>
#       <td>1.430240</td>
#       <td>0.020490</td>
#       <td>0.00</td>
#       <td>0.00</td>
#       <td>17.600</td>
#       <td>S0147</td>
#       <td>2.760980</td>
#       <td>0.03805</td>
#       <td>0.000</td>
#       <td>0.000001</td>
#       <td>0.020000</td>
#       <td>2.010</td>
#       <td>197.4</td>
#       <td>0.010</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>23.610</td>
#       <td>1.000000</td>
#       <td>0.136580</td>
#       <td>25</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0000</td>
#       <td>0.00000</td>
#       <td>0.0000</td>
#       <td>138.10001</td>
#       <td>0.060</td>
#       <td>10.0</td>
#       <td>10.0</td>
#       <td>36.463001</td>
#       <td>27.220000</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>0.000000</td>
#       <td>0.0000</td>
#       <td>228.0</td>
#       <td>0.00000</td>
#       <td>2045.8</td>
#       <td>0.00</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.00</td>
#       <td>0.00</td>
#       <td>0.000</

# %%
# %%query
# Both1 = scan(SampleToEnvironmental_temporary);
#
# Both2 = select Library, Station, pressure,
# case when depthBelow = 0.0 then depthAbove when depthAbove = 0.0 then depthBelow else (mult * depthBelow + (1 - mult) * depthAbove) end as depth,
# case when tempBelow = 0.0 then tempAbove when tempAbove = 0.0 then tempBelow else
#     (mult * tempBelow + (1 - mult) * tempAbove) end as temp,
# case when salBelow = 0.0 then salAbove when salAbove = 0.0 then salBelow else
#     (mult * salBelow + (1 - mult) * salAbove) end as sal,
# case when OXYGEN_Below = 0.0 then OXYGEN_Above when OXYGEN_Above = 0.0 then OXYGEN_Below else (mult * OXYGEN_Below + (1 - mult) * OXYGEN_Above) end as OXYGEN,case when CTDOXY_Below = 0.0 then CTDOXY_Above when CTDOXY_Above = 0.0 then CTDOXY_Below else (mult * CTDOXY_Below + (1 - mult) * CTDOXY_Above) end as CTDOXY,case when PHSPHT_Below = 0.0 then PHSPHT_Above when PHSPHT_Above = 0.0 then PHSPHT_Below else (mult * PHSPHT_Below + (1 - mult) * PHSPHT_Above) end as PHSPHT,case when SILCAT_Below = 0.0 then SILCAT_Above when SILCAT_Above = 0.0 then SILCAT_Below else (mult * SILCAT_Below + (1 - mult) * SILCAT_Above) end as SILCAT,case when NITRAT_Below = 0.0 then NITRAT_Above when NITRAT_Above = 0.0 then NITRAT_Below else (mult * NITRAT_Below + (1 - mult) * NITRAT_Above) end as NITRAT,case when NITRIT_Below = 0.0 then NITRIT_Above when NITRIT_Above = 0.0 then NITRIT_Below else (mult * NITRIT_Below + (1 - mult) * NITRIT_Above) end as NITRIT,case when TALK_Below = 0.0 then TALK_Above when TALK_Above = 0.0 then TALK_Below else (mult * TALK_Below + (1 - mult) * TALK_Above) end as TALK,case when DIC_Below = 0.0 then DIC_Above when DIC_Above = 0.0 then DIC_Below else (mult * DIC_Below + (1 - mult) * DIC_Above) end as DIC,case when H2O_2_D_DELTA_BOTTLE_Below = 0.0 then H2O_2_D_DELTA_BOTTLE_Above when H2O_2_D_DELTA_BOTTLE_Above = 0.0 then H2O_2_D_DELTA_BOTTLE_Below else (mult * H2O_2_D_DELTA_BOTTLE_Below + (1 - mult) * H2O_2_D_DELTA_BOTTLE_Above) end as H2O_2_D_DELTA_BOTTLE,case when H2O_18_D_DELTA_BOTTLE_Below = 0.0 then H2O_18_D_DELTA_BOTTLE_Above when H2O_18_D_DELTA_BOTTLE_Above = 0.0 then H2O_18_D_DELTA_BOTTLE_Below else (mult * H2O_18_D_DELTA_BOTTLE_Below + (1 - mult) * H2O_18_D_DELTA_BOTTLE_Above) end as H2O_18_D_DELTA_BOTTLE,case when Al_D_CONC_BOTTLE_Below = 0.0 then Al_D_CONC_BOTTLE_Above when Al_D_CONC_BOTTLE_Above = 0.0 then Al_D_CONC_BOTTLE_Below else (mult * Al_D_CONC_BOTTLE_Below + (1 - mult) * Al_D_CONC_BOTTLE_Above) end as Al_D_CONC_BOTTLE,case when STANDARD_DEV_Below = 0.0 then STANDARD_DEV_Above when STANDARD_DEV_Above = 0.0 then STANDARD_DEV_Below else (mult * STANDARD_DEV_Below + (1 - mult) * STANDARD_DEV_Above) end as STANDARD_DEV,case when Ba_D_CONC_BOTTLE_Below = 0.0 then Ba_D_CONC_BOTTLE_Above when Ba_D_CONC_BOTTLE_Above = 0.0 then Ba_D_CONC_BOTTLE_Below else (mult * Ba_D_CONC_BOTTLE_Below + (1 - mult) * Ba_D_CONC_BOTTLE_Above) end as Ba_D_CONC_BOTTLE,case when Cd_D_CONC_BOTTLE_Below = 0.0 then Cd_D_CONC_BOTTLE_Above when Cd_D_CONC_BOTTLE_Above = 0.0 then Cd_D_CONC_BOTTLE_Below else (mult * Cd_D_CONC_BOTTLE_Below + (1 - mult) * Cd_D_CONC_BOTTLE_Above) end as Cd_D_CONC_BOTTLE,case when Fe_D_CONC_BOTTLE_Below = 0.0 then Fe_D_CONC_BOTTLE_Above when Fe_D_CONC_BOTTLE_Above = 0.0 then Fe_D_CONC_BOTTLE_Below else (mult * Fe_D_CONC_BOTTLE_Below + (1 - mult) * Fe_D_CONC_BOTTLE_Above) end as Fe_D_CONC_BOTTLE,case when Fe_D_CONC_BOTTLE_FIA_Below = 0.0 then Fe_D_CONC_BOTTLE_FIA_Above when Fe_D_CONC_BOTTLE_FIA_Above = 0.0 then Fe_D_CONC_BOTTLE_FIA_Below else (mult * Fe_D_CONC_BOTTLE_FIA_Below + (1 - mult) * Fe_D_CONC_BOTTLE_FIA_Above) end as Fe_D_CONC_BOTTLE_FIA,case when Fe_D_CONC_BOTTLE_FIA_STANDARD_DEV_Below = 0.0 then Fe_D_CONC_BOTTLE_FIA_STANDARD_DEV_Above when Fe_D_CONC_BOTTLE_FIA_STANDARD_DEV_Above = 0.0 then Fe_D_CONC_BOTTLE_FIA_STANDARD_DEV_Below else (mult * Fe_D_CONC_BOTTLE_FIA_STANDARD_DEV_Below + (1 - mult) * Fe_D_CONC_BOTTLE_FIA_STANDARD_DEV_Above) end as Fe_D_CONC_BOTTLE_FIA_STANDARD_DEV,case when Mn_D_CONC_BOTTLE_Below = 0.0 then Mn_D_CONC_BOTTLE_Above when Mn_D_CONC_BOTTLE_Above = 0.0 then Mn_D_CONC_BOTTLE_Below else (mult * Mn_D_CONC_BOTTLE_Below + (1 - mult) * Mn_D_CONC_BOTTLE_Above) end as Mn_D_CONC_BOTTLE,case when Mn_D_CONC_BOTTLE_STANDARD_DEV_Below = 0.0 then Mn_D_CONC_BOTTLE_STANDARD_DEV_Above when Mn_D_CONC_BOTTLE_STANDARD_DEV_Above = 0.0 then Mn_D_CONC_BOTTLE_STANDARD_DEV_Below else (mult * Mn_D_CONC_BOTTLE_STANDARD_DEV_Below + (1 - mult) * Mn_D_CONC_BOTTLE_STANDARD_DEV_Above) end as Mn_D_CONC_BOTTLE_STANDARD_DEV,case when Mo_D_CONC_BOTTLE_Below = 0.0 then Mo_D_CONC_BOTTLE_Above when Mo_D_CONC_BOTTLE_Above = 0.0 then Mo_D_CONC_BOTTLE_Below else (mult * Mo_D_CONC_BOTTLE_Below + (1 - mult) * Mo_D_CONC_BOTTLE_Above) end as Mo_D_CONC_BOTTLE,case when Ni_D_CONC_BOTTLE_Below = 0.0 then Ni_D_CONC_BOTTLE_Above when Ni_D_CONC_BOTTLE_Above = 0.0 then Ni_D_CONC_BOTTLE_Below else (mult * Ni_D_CONC_BOTTLE_Below + (1 - mult) * Ni_D_CONC_BOTTLE_Above) end as Ni_D_CONC_BOTTLE,case when Pb_D_CONC_BOTTLE_Below = 0.0 then Pb_D_CONC_BOTTLE_Above when Pb_D_CONC_BOTTLE_Above = 0.0 then Pb_D_CONC_BOTTLE_Below else (mult * Pb_D_CONC_BOTTLE_Below + (1 - mult) * Pb_D_CONC_BOTTLE_Above) end as Pb_D_CONC_BOTTLE,case when U_D_CONC_BOTTLE_Below = 0.0 then U_D_CONC_BOTTLE_Above when U_D_CONC_BOTTLE_Above = 0.0 then U_D_CONC_BOTTLE_Below else (mult * U_D_CONC_BOTTLE_Below + (1 - mult) * U_D_CONC_BOTTLE_Above) end as U_D_CONC_BOTTLE,case when Zn_D_CONC_BOTTLE_Below = 0.0 then Zn_D_CONC_BOTTLE_Above when Zn_D_CONC_BOTTLE_Above = 0.0 then Zn_D_CONC_BOTTLE_Below else (mult * Zn_D_CONC_BOTTLE_Below + (1 - mult) * Zn_D_CONC_BOTTLE_Above) end as Zn_D_CONC_BOTTLE,case when Y_D_CONC_BOTTLE_Below = 0.0 then Y_D_CONC_BOTTLE_Above when Y_D_CONC_BOTTLE_Above = 0.0 then Y_D_CONC_BOTTLE_Below else (mult * Y_D_CONC_BOTTLE_Below + (1 - mult) * Y_D_CONC_BOTTLE_Above) end as Y_D_CONC_BOTTLE,case when La_D_CONC_BOTTLE_Below = 0.0 then La_D_CONC_BOTTLE_Above when La_D_CONC_BOTTLE_Above = 0.0 then La_D_CONC_BOTTLE_Below else (mult * La_D_CONC_BOTTLE_Below + (1 - mult) * La_D_CONC_BOTTLE_Above) end as La_D_CONC_BOTTLE,case when Pa_231_D_CONC_BOTTLE_Below = 0.0 then Pa_231_D_CONC_BOTTLE_Above when Pa_231_D_CONC_BOTTLE_Above = 0.0 then Pa_231_D_CONC_BOTTLE_Below else (mult * Pa_231_D_CONC_BOTTLE_Below + (1 - mult) * Pa_231_D_CONC_BOTTLE_Above) end as Pa_231_D_CONC_BOTTLE,case when Pa_231_D_CONC_BOTTLE_STANDARD_DEV_Below = 0.0 then Pa_231_D_CONC_BOTTLE_STANDARD_DEV_Above when Pa_231_D_CONC_BOTTLE_STANDARD_DEV_Above = 0.0 then Pa_231_D_CONC_BOTTLE_STANDARD_DEV_Below else (mult * Pa_231_D_CONC_BOTTLE_STANDARD_DEV_Below + (1 - mult) * Pa_231_D_CONC_BOTTLE_STANDARD_DEV_Above) end as Pa_231_D_CONC_BOTTLE_STANDARD_DEV,case when Th_230_D_CONC_BOTTLE_Below = 0.0 then Th_230_D_CONC_BOTTLE_Above when Th_230_D_CONC_BOTTLE_Above = 0.0 then Th_230_D_CONC_BOTTLE_Below else (mult * Th_230_D_CONC_BOTTLE_Below + (1 - mult) * Th_230_D_CONC_BOTTLE_Above) end as Th_230_D_CONC_BOTTLE,case when Th_230_D_CONC_BOTTLE_STANDARD_DEV_Below = 0.0 then Th_230_D_CONC_BOTTLE_STANDARD_DEV_Above when Th_230_D_CONC_BOTTLE_STANDARD_DEV_Above = 0.0 then Th_230_D_CONC_BOTTLE_STANDARD_DEV_Below else (mult * Th_230_D_CONC_BOTTLE_STANDARD_DEV_Below + (1 - mult) * Th_230_D_CONC_BOTTLE_STANDARD_DEV_Above) end as Th_230_D_CONC_BOTTLE_STANDARD_DEV,case when Th_232_D_CONC_BOTTLE_Below = 0.0 then Th_232_D_CONC_BOTTLE_Above when Th_232_D_CONC_BOTTLE_Above = 0.0 then Th_232_D_CONC_BOTTLE_Below else (mult * Th_232_D_CONC_BOTTLE_Below + (1 - mult) * Th_232_D_CONC_BOTTLE_Above) end as Th_232_D_CONC_BOTTLE,case when Th_232_D_CONC_BOTTLE_STANDARD_DEV_Below = 0.0 then Th_232_D_CONC_BOTTLE_STANDARD_DEV_Above when Th_232_D_CONC_BOTTLE_STANDARD_DEV_Above = 0.0 then Th_232_D_CONC_BOTTLE_STANDARD_DEV_Below else (mult * Th_232_D_CONC_BOTTLE_STANDARD_DEV_Below + (1 - mult) * Th_232_D_CONC_BOTTLE_STANDARD_DEV_Above) end as Th_232_D_CONC_BOTTLE_STANDARD_DEV,case when Th_234_D_CONC_BOTTLE_Below = 0.0 then Th_234_D_CONC_BOTTLE_Above when Th_234_D_CONC_BOTTLE_Above = 0.0 then Th_234_D_CONC_BOTTLE_Below else (mult * Th_234_D_CONC_BOTTLE_Below + (1 - mult) * Th_234_D_CONC_BOTTLE_Above) end as Th_234_D_CONC_BOTTLE,case when Th_234_D_CONC_BOTTLE_STANDARD_DEV_Below = 0.0 then Th_234_D_CONC_BOTTLE_STANDARD_DEV_Above when Th_234_D_CONC_BOTTLE_STANDARD_DEV_Above = 0.0 then Th_234_D_CONC_BOTTLE_STANDARD_DEV_Below else (mult * Th_234_D_CONC_BOTTLE_STANDARD_DEV_Below + (1 - mult) * Th_234_D_CONC_BOTTLE_STANDARD_DEV_Above) end as Th_234_D_CONC_BOTTLE_STANDARD_DEV
# from Both1; --where Station = 1;
#
# AboveNotBelow = scan(AboveNotBelow);
# BelowNotAbove = scan(BelowNotAbove);
# Both3 = Both2 + AboveNotBelow + BelowNotAbove;
# Store(Both3, SampleToEnvironmental, [Library]);
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Al_D_CONC_BOTTLE</th>
#       <th>Ba_D_CONC_BOTTLE</th>
#       <th>CTDOXY</th>
#       <th>Cd_D_CONC_BOTTLE</th>
#       <th>DIC</th>
#       <th>Fe_D_CONC_BOTTLE</th>
#       <th>Fe_D_CONC_BOTTLE_FIA</th>
#       <th>Fe_D_CONC_BOTTLE_FIA_STANDARD_DEV</th>
#       <th>H2O_18_D_DELTA_BOTTLE</th>
#       <th>H2O_2_D_DELTA_BOTTLE</th>
#       <th>La_D_CONC_BOTTLE</th>
#       <th>Library</th>
#       <th>Mn_D_CONC_BOTTLE</th>
#       <th>Mn_D_CONC_BOTTLE_STANDARD_DEV</th>
#       <th>Mo_D_CONC_BOTTLE</th>
#       <th>NITRAT</th>
#       <th>NITRIT</th>
#       <th>Ni_D_CONC_BOTTLE</th>
#       <th>OXYGEN</th>
#       <th>PHSPHT</th>
#       <th>Pa_231_D_CONC_BOTTLE</th>
#       <th>Pa_231_D_CONC_BOTTLE_STANDARD_DEV</th>
#       <th>Pb_D_CONC_BOTTLE</th>
#       <th>SILCAT</th>
#       <th>STANDARD_DEV</th>
#       <th>Station</th>
#       <th>TALK</th>
#       <th>Th_230_D_CONC_BOTTLE</th>
#       <th>Th_230_D_CONC_BOTTLE_STANDARD_DEV</th>
#       <th>Th_232_D_CONC_BOTTLE</th>
#       <th>Th_232_D_CONC_BOTTLE_STANDARD_DEV</th>
#       <th>Th_234_D_CONC_BOTTLE</th>
#       <th>Th_234_D_CONC_BOTTLE_STANDARD_DEV</th>
#       <th>U_D_CONC_BOTTLE</th>
#       <th>Y_D_CONC_BOTTLE</th>
#       <th>Zn_D_CONC_BOTTLE</th>
#       <th>depth</th>
#       <th>pressure</th>
#       <th>sal</th>
#       <th>temp</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>19.404900</td>
#       <td>0.000000</td>
#       <td>216.666667</td>
#       <td>0.042100</td>
#       <td>2086.500000</td>
#       <td>0.090000</td>
#       <td>0.074150</td>
#       <td>0.002930</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>18.170000</td>
#       <td>S0159</td>
#       <td>0.829270</td>
#       <td>0.004880</td>
#       <td>0.000000</td>
#       <td>2.722223</td>
#       <td>0.225556</td>
#       <td>2.650000</td>
#       <td>0.000000</td>
#       <td>0.187778</td>
#       <td>0.00000</td>
#       <td>0.00000</td>
#       <td>21.610000</td>
#       <td>1.620000</td>
#       <td>0.146340</td>
#       <td>11</td>
#       <td>2406.300000</td>
#       <td>0.00000</td>
#       <td>0.00000</td>
#       <td>0.00000</td>
#       <td>0.00000</td>
#       <td>39.122000</td>
#       <td>1.951220</td>
#       <td>0.000000</td>
#       <td>143.620000</td>
#       <td>0.050000</td>
#       <td>74.444444</td>
#       <td>75.0</td>
#       <td>36.364111</td>
#       <td>18.099778</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>6.039020</td>
#       <td>43.272200</td>
#       <td>123.785000</td>
#       <td>0.211600</td>
#       <td>2176.400000</td>
#       <td>0.830000</td>
#       <td>0.741460</td>
#       <td>0.019510</td>
#       <td>0.260000</td>
#       <td>1.610000</td>
#       <td>17.180000</td>
#       <td>S0204</td>
#       <td>0.204880</td>
#       <td>0.001950</td>
#       <td>137.491000</td>
#       <td>20.008000</td>
#       <td>0.019500</td>
#       <td>3.580000</td>
#       <td>0.000000</td>
#       <td>1.311500</td>
#       <td>0.00000</td>
#       <td>0.00000</td>
#       <td>16.900000</td>
#       <td>6.889500</td>
#       <td>0.068290</td>
#       <td>17</td>
#       <td>2306.600000</td>
#       <td>0.00000</td>
#       <td>0.00000</td>
#       <td>0.00000</td>
#       <td>0.00000</td>
#       <td>42.331700</td>
#       <td>0.868290</td>
#       <td>12.915100</td>
#       <td>103.900000</td>
#       <td>0.280000</td>
#       <td>149.100000</td>
#       <td>150.0</td>
#       <td>35.333100</td>
#       <td>13.454450</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>147.132000</td>
#       <td>0.000000</td>
#       <td>2183.300000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>S0026</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>20.460000</td>
#       <td>0.010000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>1.320000</td>
#       <td>0.00000</td>
#       <td>0.00000</td>
#       <td>0.000000</td>
#       <td>6.140000</td>
#       <td>0.000000</td>
#       <td>15</td>
#       <td>2324.700000</td>
#       <td>0.00000</td>
#       <td>0.00000</td>
#       <td>0.00000</td>
#       <td>0.00000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>178.800000</td>
#       <td>180.0</td>
#       <td>35.824280</td>
#       <td>15.119640</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>27.814600</td>
#       <td>0.000000</td>
#       <td>194.043802</td>
#       <td>0.010500</td>
#       <td>2115.500000</td>
#       <td>0.300000</td>
#       <td>0.262440</td>
#       <td>0.004880</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>14.590000</td>
#       <td>S0104</td>
#       <td>0.321950</td>
#       <td>0.009760</td>
#       <td>0.000000</td>
#       <td>2.933058</td>
#       <td>0.020000</td>
#       <td>2.170000</td>
#       <td>0.000000</td>
#       <td>0.113306</td>
#       <td>0.00000</td>
#       <td>0.00000</td>
#       <td>21.330000</td>
#       <td>1.166529</td>
#       <td>0.117070</td>
#       <td>24</td>
#       <td>2397.600000</td>
#       <td>0.00000</td>
#       <td>0.00000</td>
#       <td>0.00000</td>
#       <td>0.00000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>135.850010</td>
#       <td>0.080000</td>
#       <td>283.933884</td>
#       <td>286.0</td>
#       <td>36.631096</td>
#       <td>18.848942</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>14.926800</td>
#       <td>42.213700</td>
#       <td>195.526667</td>
#       <td>0.001900</td>
#       <td>2042.800000</td>
#       <td>0.110000</td>
#       <td>0.078050</td>
#       <td>0.068290</td>
#       <td>0.890000</td>
#       <td>7.360000</td>
#       <td>17.130000</td>
#       <td>S0200</td>
#       <td>1.560980</td>
#       <td>0.029270</td>
#       <td>136.229000</td>
#       <td>0.000001</td>
#       <td>0.023000</td>
#       <td>2.290000</td>
#       <td>0.000000</td>
#       <td>0.087000</td>
#       <td>0.00000</td>
#       <td>0.00000</td>
#       <td>17.570000</td>
#       <td>0.254000</td>
#       <td>0.097560</td>
#       <td>16</td>
#       <td>2386.800000</td>
#       <td>0.00000</td>
#       <td>0.00000</td>
#       <td>0.00000</td>
#       <td>0.00000</td>
#       <td>39.785400</td>
#       <td>0.839020</td>
#       <td>12.952200</td>
#       <td>102.700000</td>
#       <td>0.070000</td>
#       <td>49.700000</td>
#       <td>50.0</td>
#       <td>36.448166</td>
#       <td>28.647167</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>27.051762</td>
#       <td>0.000000</td>
#       <td>186.789879</td>
#       <td>0.005394</td>
#       <td>2111.400000</td>
#       <td>0.422874</td>
#       <td>0.365439</td>
#       <td>0.006906</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>14.419028</td>
#       <td>S0103</td>
#       <td>0.355246</td>
#       <td>0.004956</td>
#       <td>0.000000</td>
#       <td>2.223482</td>
#       <td>0.032611</td>
#       <td>2.153968</td>
#       <td>0.000000</td>
#       <td>0.076579</td>
#       <td>0.00000</td>
#       <td>0.00000</td>
#       <td>21.697733</td>
#       <td>1.009919</td>
#       <td>0.188527</td>
#       <td>24</td>
#       <td>2403.000000</td>
#       <td>0.00000</td>
#       <td>0.00000</td>
#       <td>0.00000</td>
#       <td>0.00000</td>
#       <td>50.454068</td>
#       <td>2.770414</td>
#       <td>0.000000</td>
#       <td>132.671377</td>
#       <td>2.503806</td>
#       <td>233.344130</td>
#       <td>235.0</td>
#       <td>36.706690</td>
#       <td>19.628664</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>10.680126</td>
#       <td>41.624400</td>
#       <td>208.702400</td>
#       <td>0.002838</td>
#       <td>2078.240000</td>
#       <td>0.205920</td>
#       <td>0.153150</td>
#       <td>0.002930</td>
#       <td>0.750000</td>
#       <td>6.230000</td>
#       <td>15.630880</td>
#       <td>S0247</td>
#       <td>1.499004</td>
#       <td>0.020162</td>
#       <td>147.770000</td>
#       <td>0.014401</td>
#       <td>0.017400</td>
#       <td>2.255920</td>
#       <td>0.000000</td>
#       <td>0.103440</td>
#       <td>0.00000</td>
#       <td>0.00000</td>
#       <td>14.693120</td>
#       <td>0.256080</td>
#       <td>0.076645</td>
#       <td>

# %% [markdown]
# # Load GC Content conversion table

# %% [markdown]
# The following csv file maps 11-mers to the proportion of bases inside it that are 'G' or 'C'.
# The file was generated from a standalone Java program, enumerating all 4^11 11-mers.

# %%
# %%query
# T1 = load("file:///home/gridsan/dhutchison/gits/istc_oceanography/diversity/kmer_gc.csv",
# csv(schema(kmer:string,gc_content:float),skip=1,delimiter=","));
# store(T1, Kmer11_gc_content);

# %%
# %%query
# Tgc = scan(Kmer11_gc_content);
# Tnorm = scan(kmercounts_combined_scaled);
#
# TsampGC = select n.sampleid, sum(n.norm_cnt * g.gc_content) as gc_content
# from Tgc g, Tnorm n
# where n.kmer = g.kmer;
#
# store(TsampGC, sample_gc, [sampleid]);

# %% [markdown]
# # t-SNE Ordering and Visualization

# %% [markdown]
# We used a Matlab script implementing t-SNE to cluster together samples, using the Bray-Curtis distance matrix as input.
#
# By running t-SNE with 1 output dimension and tweaking the perplexity parameter (2.5 is pretty good), we can derive a ordering that places similar samples near each other.

# %% [markdown]
# The results of this step are in the following dataset:

# %%
# %%query
# T1 = load("file:///home/gridsan/dhutchison/gits/istc_oceanography/parse_fastq/tSNE_matlab/t-SNE-BC-1d-labels.csv",
# csv(schema(sampleid:string,clusterid:string),skip=0,delimiter=","));
# store(T1, t-SNE-BC-1d-labels);

# %% [markdown]
# # Join all sample data together

# %% [markdown]
# The following queries combine all information for each sample into one relation, for use on the visualization screen.

# %%
# %%query
# E = scan(SampleToEnvironmental);
# S = scan(kmercntnorm_11_forward_stats);
# SSUM = scan(kmercnt_11_sum_Psample);
# G = scan(sample_gc);
# L = scan(t-SNE-BC-1d-labels);
# R = select * from E e, S s, G g, L l, SSUM ssum
# where e.Library = s.sampleid and e.Library = g.sampleid and e.Library = l.sampleid and s.sampleid = ssum.sampleid;
# store(R, SampleToEnvironmental_All);

# %% [markdown]
# # Degree Distribution

# %% [markdown]
# An easy initial way to characterize a distribution is by its degree distribution.
# We plotted the degree distribution of the kmer frequencies of a few samples.
# The x-axis is the frequency, and the y-axis is how many kmers occurred with that frequency, normalized by 4^11.

# %%
Tkmer = scan(kmercntnorm_11_forward_Pkmer);

Thist = select sampleid, norm_cnt, count(norm_cnt) as cnt_norm_cnt
from Tkmer
where sampleid = "S0002";

store(Thist, kmer_11_forward_degree_dist);

# %%
#hist = MyriaRelation("kmer_11_forward_degree_dist").to_dataframe()
#hist.plot()

# %%
#TODO: Python to generate these plots below

# %% [markdown]
# <img src="kmer-degree-distribution-normalized.png" />

# %% [markdown]
# The results surprised us. We did not expect to see such a nice curve. Keep in mind the logarithmic x-axis, which means this is not a normal distribution.
#
# To test whether the degree distribution of the 11-mers was significant or an artifact of a random distribution, we simulated drawing kmers at random in the following figure.

# %% [markdown]
# <img src="kmer-degree-distribution-normalized-withrandom3.png" />

# %% [markdown]
# However, we must be careful in how we generate random sequences.
# The actual process in which samples are collected is different: we must consider overlapping and duplication.
# The same organism can be in the sample more than once (and bacteria can have multiple copies of some of their DNA in plasmids).
#
# We therefore generated a new random sequence by first fixing a long sequence of about 90M base pairs, and sampling from that sequence at random points, restarting at a new random location approcimately every 200 bases (Normal with mean 200, standard deviation 25), until we collect about 900M kmers.
#
# The result is the red triangle distribution below, which matches the empirical distirbutions from real samples more closely.

# %% [markdown]
# <img src="kmer-degree-distribution-normalized-withrandom4.png" />

# %% [markdown]
# Note that these distributions are very sensitive to k.  We get a very different graph with k=13, particularly because many 13-mers are not present whereas pretty much every 11-mer has a count of at least 1.

# %% [markdown]
# # Conclusion

# %% [markdown]
# We end with some words on our approach.
# Kmers are just one approach to achieve a high goal: identify the species and genome each read came from in a sample.  If we cannot reach genome-level resolution, then at least identify the species or genus.
#
# One method for identifying genomes is sequence alignment a la BLAST and related hidden Markov methods like HMMER.  While BLAST/HMMER has seen many advances---GPU parallelization, breaking the algorithm into stages, etc.---this method does not yet scale to the level of data that we see in our GA02/GA03 datasets or Tara.
#
# In kmer analysis, we mix up the kmers from all the reads in each sample in order to characterize the sample at a coarser level.  Lower 'k's and GC content give overall characterizations, and higher 'k's may identify particular species, genuses, or genomes.  Someday, we may use a multi-resolution model that bridges between lower 'k's and higher 'k's, or we might start including more alignment information.  To test the viability of any kmer approach, we must ask the following questions:
#
# > What is the strength of a genome's identifying signal in a mixture of kmers, as we add more and more different genomes to the sample?  Surely it is easy to identify a genome from reads of a sample consisting purely of that genome.  What if the sample contains 2 different genomes?  3? 400? 5M? 6T?  Does it depend on how closely related the various genomes are (say, in Hamming/edit distance), or on the abundance of each genome in the ocean sample?
#
# Simulation and signal processing theory can answer these questions, at least with a lower bound.  We ought to know how mixed up a set of samples might be before we cannot distinguish signal from noise.
